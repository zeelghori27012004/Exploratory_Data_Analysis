# %% [markdown]
# # **Link of the colab notebook :**
# https://colab.research.google.com/drive/1hH12iuzH8RkR6sSw_k3IvYRa0TfSAObI?usp=sharing
#
# # **Link of the dataset:**
# https://drive.google.com/file/d/1wfez4vnyXcBe-sKEVqIbFLq09WRoLNKv/view?usp=sharing

# %% [markdown]
# ### **Step 1: Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualisation style
sns.set(style="whitegrid")

# %% [markdown]
# ### **Step 2: Loading the Dataset**

# %%
#mount the gdrive
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Exploratory_Data_Analysis/Dataset/IMdB_India_Top250.csv')
df.head(10)
# Out:
#           Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0          12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1           Gol Maal             1979            2 hours      8.5     20K
# 2           Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3            Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4   The World of Apu             1959   1 hour 45 minutes     8.4     17K
# 5         Anbe Sivam             2003  2 hours 40 minutes     8.6     26K
# 6  Pariyerum Perumal             2018  2 hours 34 minutes     8.7     19K
# 7           3 Idiots             2009  2 hours 50 minutes     8.4    441K
# 8              #Home             2021  2 hours 38 minutes     8.8     16K
# 9       Black Friday             2004  2 hours 23 minutes     8.4     22K
#
#            Film Industry                   Genre              Director  \
# 0      Bollywood (Hindi)        Drama, Biography    Vidhu Vinod Chopra
# 1      Bollywood (Hindi)                  Comedy  Hrishikesh Mukherjee
# 2      Kollywood (Tamil)            Crime, Drama   Nithilan Saminathan
# 3      Kollywood (Tamil)            Crime, Drama           Mani Ratnam
# 4         Bengali Cinema                   Drama          Satyajit Ray
# 5      Kollywood (Tamil)           Drama, Comedy             Sundar C.
# 6      Kollywood (Tamil)           Drama, Social         Mari Selvaraj
# 7      Bollywood (Hindi)           Comedy, Drama       Rajkumar Hirani
# 8  Mollywood (Malayalam)           Drama, Family          Rojin Thomas
# 9      Bollywood (Hindi)  Crime, Drama, Thriller        Anurag Kashyap
#
#   Box office collection  User reviews                        Awards  \
# 0           $138,288.00           945      23 wins & 32 nominations
# 1                   NIL            48         3 wins & 1 nomination
# 2           $975,543.00           370                 2 nominations
# 3           $120,481.93           237         7 wins & 1 nomination
# 4           $134,241.00            62  4 wins & 2 nominations total
# 5                   NIL           115        2 wins & 3 nominations
# 6                   NIL           169       11 wins & 5 nominations
# 7        $60,262,836.00          1000      64 wins & 30 nominations
# 8                   NIL           541        3 wins & 2 nominations
# 9         $1,610,897.00            88         1 win & 7 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
# 5  Two men, one young and arrogant, the other dam...
# 6  A law student from a lower caste begins a frie...
# 7  Two friends are searching for their long lost ...
# 8  Oliver Twist (Indrans) wants to be tech-savvy ...
# 9  A film about the investigations following the ...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi
# 5                    Disney+ Hotstar
# 6                 Amazon Prime Video
# 7        Netflix, Amazon Prime Video
# 8                 Amazon Prime Video
# 9                            YouTube

# %% [markdown]
# ### **Step 3: Exploring the Data**

# %%
# Get basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Movie name             250 non-null    object
#  1   Year of release        250 non-null    int64
#  2   Watch  hour            250 non-null    object
#  3   Rating                 250 non-null    float64
#  4   Ratedby                250 non-null    object
#  5   Film Industry          250 non-null    object
#  6   Genre                  250 non-null    object
#  7   Director               250 non-null    object
#  8   Box office collection  250 non-null    object
#  9   User reviews           250 non-null    int64
#  10  Awards                 250 non-null    object
#  11  Description            250 non-null    object
#  12  Streaming platform     250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %%
# Summary statistics for numerical columns
df.describe()
# Out:
#        Year of release      Rating  User reviews
# count       250.000000  250.000000     250.00000
# mean       2008.388000    8.190400     222.18400
# std          14.708597    0.252513     388.15949
# min        1955.000000    7.700000      10.00000
# 25%        2003.000000    8.000000      39.00000
# 50%        2013.000000    8.150000      94.50000
# 75%        2018.000000    8.300000     231.50000
# max        2024.000000    9.100000    3300.00000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   0
# Description              0
# Streaming platform       0
# dtype: int64

# %% [markdown]
# # **IMPORTANT NOTE :**
#
# Here the missing values are not NaN but are written as NIL so df.isnull().sum() cannot identify them as missing value. So we have to write Null/NaN inplace of NIL value so that function df.isnull().sum() can identify it.

# %%
# Strip whitespace from column names
df.columns = df.columns.str.strip()
# Print columns to verify the correct name
print(df.columns)

# Replace "NIL" with NaN in the entire DataFrame
df.replace("NIL", np.nan, inplace=True)

# Replace "NIL" with NaN in the 'Box Office Collection' column specifically
df['Box office collection'].replace("NIL", np.nan, inplace=True)
# Out:
# Index(['Movie name', 'Year of release', 'Watch  hour', 'Rating', 'Ratedby',
#        'Film Industry', 'Genre', 'Director', 'Box office collection',
#        'User reviews', 'Awards', 'Description', 'Streaming platform'],
#       dtype='object')
# <ipython-input-7-403048cc3d66>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Box office collection'].replace("NIL", np.nan, inplace=True)

# %%
# Function to clean the 'Box office collection' column
def clean_box_office(value):
    value = value.strip()  # Remove leading/trailing spaces
    if value == 'NIL' or value == '$0' or value == '$0.00':
        return 0.0
    else:
        # Remove $ and commas, then convert to float
        return float(value.replace('$', '').replace(',', ''))

# Apply the function to clean the 'Box office collection' column
df['Box office collection'] = df['Box office collection'].apply(clean_box_office)

# Replace 0.0 with NaN in the 'Box office collection' column
df['Box office collection'].replace(0.0, np.nan, inplace=True)

# Print the result to verify
df.head()
# Out:
# <ipython-input-8-4611e4fb9144>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Box office collection'].replace(0.0, np.nan, inplace=True)
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards  \
# 0              138288.00           945      23 wins & 32 nominations
# 1                    NaN            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Movie name                0
# Year of release           0
# Watch  hour               0
# Rating                    0
# Ratedby                   0
# Film Industry             0
# Genre                     0
# Director                  0
# Box office collection    52
# User reviews              0
# Awards                    9
# Description               0
# Streaming platform        0
# dtype: int64

# %%
# Unique values in categorical columns
cols = df.columns
num_cols = df._get_numeric_data().columns
num_cols
cat_cols = list(set(cols) - set(num_cols))

df[cat_cols].nunique()
# Out:
# Movie name            248
# Director              182
# Film Industry           9
# Streaming platform     28
# Ratedby               110
# Awards                184
# Description           250
# Genre                 106
# Watch  hour            79
# dtype: int64

# %%
# Unique values in categorical columns
print(df['Streaming platform'].unique())
print(df['Film Industry'].unique())
# Out:
# ['SonyLIV' 'Amazon Prime Video, YouTube, Zee5' 'Netflix'
#  'Amazon Prime Video, YouTube' 'Amazon Prime Video, Hoichoi'
#  'Disney+ Hotstar' 'Amazon Prime Video' 'Netflix, Amazon Prime Video'
#  'YouTube' 'Voot, Amazon Prime Video' 'Netflix, Disney+ Hotstar'
#  'Yet to be released/Not available' 'Zee5' 'Amazon Prime Video, Hotstar'
#  'Hotstar' 'Disney+ Hotstar, Amazon Prime Video' 'Mubi'
#  'Not available on major streaming platforms'
#  'Amazon Prime Video, Disney+ Hotstar' 'Disney+ Hotstar, Netflix'
#  'Netflix, Zee5' 'Amazon Prime Video, Zee5' 'Amazon Prime Video, Netflix'
#  'Hoichoi' 'Voot' 'Netflix, SonyLIV' 'Sun NXT' 'Zee5, Amazon Prime Video']
# ['Bollywood (Hindi)' 'Kollywood (Tamil)' 'Bengali Cinema'
#  'Mollywood (Malayalam)' 'Sandalwood (Kannada)' 'Tollywood (Telugu)'
#  'Marathi Cinema' 'South Korean Cinema' 'Hollywood (English)']

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()

# look at the number of missing points
missing_values_count
# Out:
# Movie name                0
# Year of release           0
# Watch  hour               0
# Rating                    0
# Ratedby                   0
# Film Industry             0
# Genre                     0
# Director                  0
# Box office collection    52
# User reviews              0
# Awards                    9
# Description               0
# Streaming platform        0
# dtype: int64

# %% [markdown]
# Find the probability of missing value.

# %%
# how many total missing values do we have?
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 1.8769230769230771

# %% [markdown]
# ### **Step 4: Data Cleaning**

# %% [markdown]
# By looking at the data, it can be seen that missing column has information on the Box office collection and Awards.
#
# This means that some columns values are probably missing because they were not recorded, rather than because they don't exist. So, it would make sense for us to try and guess what they should be rather than just leaving them as NA's.
#
# On the other hand, there are some columns have lot of missing fields. In this case, though, the field is missing because if there was no value(does not exist) then it doesn't make sense to guess it . For this column, it would make more sense to either leave it empty or to add a third value like "neither" and use that to replace the NA's.

# %%
# Drop rows with missing values (if any)
df_cleaned = df.dropna()

# %%
# Check for missing values
df_cleaned.isnull().sum()
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   0
# Description              0
# Streaming platform       0
# dtype: int64

# %% [markdown]
# ### **Markdown:**
# First, we check how many rows and columns contain missing data. If only a small portion of the dataset is missing values, dropping rows may be acceptable.
#
# We also calculate the percentage of rows with missing values to ensure we're not losing too much data. Generally, if more than 5-10% of the dataset has missing values, alternative methods like imputation should be considered.
#
# After dropping rows, we verify the dataset's new shape to confirm the number of rows left.

# %%
# Remove duplicates
df_cleaned = df_cleaned.drop_duplicates()

# %% [markdown]
# ### **Step 5: Data Transformation**

# %% [markdown]
# **Filtering and Sorting**

# %% [markdown]
# a. Filter the dataset to display only movies released after the year 2000.

# %%
df['Year of release'] > 2000
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 245    False
# 246     True
# 247     True
# 248     True
# 249     True
# Name: Year of release, Length: 250, dtype: bool

# %%
movies_after_2000 = df[df['Year of release'] > 2000]
movies_after_2000
# Out:
#                    Movie name  Year of release         Watch  hour  Rating  \
# 0                   12th Fail             2023  2 hours 27 minutes     8.9
# 2                    Maharaja             2024  2 hours 30 minutes     8.6
# 5                  Anbe Sivam             2003  2 hours 40 minutes     8.6
# 6           Pariyerum Perumal             2018  2 hours 34 minutes     8.7
# 7                    3 Idiots             2009  2 hours 50 minutes     8.4
# ..                        ...              ...                 ...     ...
# 244          Angamaly Diaries             2017  2 hours 12 minutes     7.9
# 246  Hazaaron Khwaishein Aisi             2003            2 hours      7.9
# 247                    Ghilli             2004  2 hours 40 minutes     8.1
# 248  Mukundan Unni Associates             2022   2 hours 8 minutes     7.9
# 249                Happy Days             2007  2 hours 33 minutes     7.9
#
#     Ratedby          Film Industry                     Genre  \
# 0      126K      Bollywood (Hindi)          Drama, Biography
# 2       37K      Kollywood (Tamil)              Crime, Drama
# 5       26K      Kollywood (Tamil)             Drama, Comedy
# 6       19K      Kollywood (Tamil)             Drama, Social
# 7      441K      Bollywood (Hindi)             Comedy, Drama
# ..      ...                    ...                       ...
# 244    6.8K  Mollywood (Malayalam)              Crime, Drama
# 246    5.3K      Bollywood (Hindi)  Political Drama, Romance
# 247     17K      Kollywood (Tamil)             Action, Drama
# 248    6.2K  Mollywood (Malayalam)             Satire, Drama
# 249    6.3K     Tollywood (Telugu)    Drama, Romance, Comedy
#
#                  Director  Box office collection  User reviews  \
# 0      Vidhu Vinod Chopra              138288.00           945
# 2     Nithilan Saminathan              975543.00           370
# 5               Sundar C.                    NaN           115
# 6           Mari Selvaraj                    NaN           169
# 7         Rajkumar Hirani            60262836.00          1000
# ..                    ...                    ...           ...
# 244  Lijo Jose Pellissery              661915.00            39
# 246         Sudhir Mishra                    NaN            44
# 247               Dharani              163961.00            47
# 248  Abhinav Sunder Nayak               44990.00            62
# 249        Sekhar Kammula              361445.78            16
#
#                        Awards  \
# 0    23 wins & 32 nominations
# 2               2 nominations
# 5      2 wins & 3 nominations
# 6     11 wins & 5 nominations
# 7    64 wins & 30 nominations
# ..                        ...
# 244    2 wins & 6 nominations
# 246    8 wins & 9 nominations
# 247    2 wins & 2 nominations
# 248                     1 win
# 249                    7 wins
#
#                                            Description  \
# 0    The real-life story of IPS Officer Manoj Kumar...
# 2    A barber seeks vengeance after his home is bur...
# 5    Two men, one young and arrogant, the other dam...
# 6    A law student from a lower caste begins a frie...
# 7    Two friends are searching for their long lost ...
# ..                                                 ...
# 244  Vincent Pepe who wanted to be a powerful leade...
# 246  Set in the backdrop of Indian Emergency 1975, ...
# 247  Velu, an aspiring kabaddi player, goes to Madu...
# 248  Advocate Mukundan Unni, played by Vineeth Sree...
# 249  A group of eight youngsters from an engineerin...
#
#               Streaming platform
# 0                        SonyLIV
# 2                        Netflix
# 5                Disney+ Hotstar
# 6             Amazon Prime Video
# 7    Netflix, Amazon Prime Video
# ..                           ...
# 244                      Netflix
# 246           Amazon Prime Video
# 247              Disney+ Hotstar
# 248              Disney+ Hotstar
# 249           Amazon Prime Video
#
# [202 rows x 13 columns]

# %% [markdown]
# b. Sort the DataFrame by IMDB Rating in descending order.

# %%
sorted_by_rating = df.sort_values(by='Rating', ascending=False)
sorted_by_rating
# Out:
#                Movie name  Year of release         Watch  hour  Rating  \
# 27              Mayabazar             1957  3 hours 12 minutes     9.1
# 17              Sandesham             1991  2 hours 18 minutes     9.0
# 0               12th Fail             2023  2 hours 27 minutes     8.9
# 14               Kireedam             1989   2 hours 4 minutes     8.9
# 8                   #Home             2021  2 hours 38 minutes     8.8
# ..                    ...              ...                 ...     ...
# 237  Nayak: The Real Hero             2001   3 hours 7 minutes     7.8
# 236      Stanley Ka Dabba             2011   1 hour 36 minutes     7.8
# 220               Lakshya             2004   3 hours 6 minutes     7.8
# 243           Vicky Donor             2012   2 hours 6 minutes     7.7
# 245             Mr. India             1987  2 hours 59 minutes     7.7
#
#     Ratedby          Film Industry                     Genre  \
# 27     5.9K     Tollywood (Telugu)     Fantasy, Mythological
# 17     5.4K  Mollywood (Malayalam)  Political Satire, Comedy
# 0      126K      Bollywood (Hindi)          Drama, Biography
# 14     8.8K  Mollywood (Malayalam)             Drama, Family
# 8       16K  Mollywood (Malayalam)             Drama, Family
# ..      ...                    ...                       ...
# 237     18K      Bollywood (Hindi)   Action, Political Drama
# 236    7.7K      Bollywood (Hindi)             Drama, Family
# 220     26K      Bollywood (Hindi)                War, Drama
# 243     46K      Bollywood (Hindi)             Comedy, Drama
# 245     17K      Bollywood (Hindi)    Action, Sci-Fi, Family
#
#                  Director  Box office collection  User reviews  \
# 27   Kadiri Venkata Reddy                    NaN            39
# 17       Sathyan Anthikad                    NaN            17
# 0      Vidhu Vinod Chopra               138288.0           945
# 14           Sibi Malayil               181001.0            33
# 8            Rojin Thomas                    NaN           541
# ..                    ...                    ...           ...
# 237            S. Shankar                    NaN            20
# 236           Amole Gupte              1241102.0            44
# 220         Farhan Akhtar              5859242.0           107
# 243        Shoojit Sircar              6456358.0            82
# 245         Shekhar Kapur                    NaN            25
#
#                        Awards  \
# 27                        NaN
# 17                     2 wins
# 0    23 wins & 32 nominations
# 14                      1 win
# 8      3 wins & 2 nominations
# ..                        ...
# 237             4 nominations
# 236    4 wins & 6 nominations
# 220   6 wins & 14 nominations
# 243  43 wins & 37 nominations
# 245                     1 win
#
#                                            Description  \
# 27   Balarama promises Subhadra to get his daughter...
# 17   A satire on contemporary Kerala politics where...
# 0    The real-life story of IPS Officer Manoj Kumar...
# 14   The life of a young man turns upside down when...
# 8    Oliver Twist (Indrans) wants to be tech-savvy ...
# ..                                                 ...
# 237  A man accepts a challenge by the chief ministe...
# 236  A school-teacher, who forces children to share...
# 220  An aimless, jobless, irresponsible grown man j...
# 243  A man is brought in by an infertility doctor t...
# 245  A poor but big-hearted man takes orphans into ...
#
#               Streaming platform
# 27   Amazon Prime Video, YouTube
# 17            Amazon Prime Video
# 0                        SonyLIV
# 14            Amazon Prime Video
# 8             Amazon Prime Video
# ..                           ...
# 237           Amazon Prime Video
# 236              Disney+ Hotstar
# 220           Amazon Prime Video
# 243  Amazon Prime Video, Netflix
# 245     Zee5, Amazon Prime Video
#
# [250 rows x 13 columns]

# %% [markdown]
# c. Create a new DataFrame that contains only movies with an IMDB rating greater than 8.5.

# %%
high_rated_movies = df[df['Rating'] > 8.5]
high_rated_movies
# Out:
#                      Movie name  Year of release         Watch  hour  Rating  \
# 0                     12th Fail             2023  2 hours 27 minutes     8.9
# 2                      Maharaja             2024  2 hours 30 minutes     8.6
# 3                       Nayakan             1987  2 hours 25 minutes     8.7
# 5                    Anbe Sivam             2003  2 hours 40 minutes     8.6
# 6             Pariyerum Perumal             2018  2 hours 34 minutes     8.7
# 8                         #Home             2021  2 hours 38 minutes     8.8
# 10            Manichithrathazhu             1993  2 hours 49 minutes     8.7
# 11   Rocketry: The Nambi Effect             2022  2 hours 37 minutes     8.7
# 13                  777 Charlie             2022  2 hours 44 minutes     8.7
# 14                     Kireedam             1989   2 hours 4 minutes     8.9
# 15            C/o Kancharapalem             2018  2 hours 32 minutes     8.8
# 17                    Sandesham             1991  2 hours 18 minutes     9.0
# 21              Soorarai Pottru             2020  2 hours 33 minutes     8.7
# 23                    Natsamrat             2016  2 hours 46 minutes     8.8
# 27                    Mayabazar             1957  3 hours 12 minutes     9.1
# 28                 Nadodikkattu             1987  2 hours 38 minutes     8.8
# 29                 Thevar Magan             1992  2 hours 25 minutes     8.7
# 31                     Jai Bhim             2021  2 hours 44 minutes     8.7
# 40         Nuvvu Naaku Nachchav             2001   3 hours 4 minutes     8.8
# 49                    Devasuram             1993   3 hours 7 minutes     8.7
# 57                      Peranbu             2018  2 hours 27 minutes     8.7
# 58                     Chithram             1988  2 hours 39 minutes     8.6
# 71                     Spadikam             1995  2 hours 30 minutes     8.6
# 131   A Northern Story of Valor             1989  2 hours 48 minutes     8.7
#
#     Ratedby          Film Industry                     Genre  \
# 0      126K      Bollywood (Hindi)          Drama, Biography
# 2       37K      Kollywood (Tamil)              Crime, Drama
# 3       25K      Kollywood (Tamil)              Crime, Drama
# 5       26K      Kollywood (Tamil)             Drama, Comedy
# 6       19K      Kollywood (Tamil)             Drama, Social
# 8       16K  Mollywood (Malayalam)             Drama, Family
# 10      13K  Mollywood (Malayalam)   Horror, Thriller, Drama
# 11      59K      Bollywood (Hindi)          Biography, Drama
# 13      41K   Sandalwood (Kannada)          Adventure, Drama
# 14     8.8K  Mollywood (Malayalam)             Drama, Family
# 15     8.2K     Tollywood (Telugu)          Drama, Anthology
# 17     5.4K  Mollywood (Malayalam)  Political Satire, Comedy
# 21     125K      Kollywood (Tamil)          Drama, Biography
# 23     7.3K         Marathi Cinema            Drama, Tragedy
# 27     5.9K     Tollywood (Telugu)     Fantasy, Mythological
# 28     5.9K  Mollywood (Malayalam)  Satire, Comedy, Thriller
# 29     8.2K      Kollywood (Tamil)             Drama, Family
# 31     219K      Kollywood (Tamil)              Drama, Legal
# 40     5.7K     Tollywood (Telugu)           Romance, Comedy
# 49     6.5K  Mollywood (Malayalam)             Drama, Action
# 57      17K      Kollywood (Tamil)                     Drama
# 58     6.2K  Mollywood (Malayalam)             Comedy, Drama
# 71       7K  Mollywood (Malayalam)             Action, Drama
# 131    6.4K      Kollywood (Tamil)             Drama, Action
#
#                  Director  Box office collection  User reviews  \
# 0      Vidhu Vinod Chopra              138288.00           945
# 2     Nithilan Saminathan              975543.00           370
# 3             Mani Ratnam              120481.93           237
# 5               Sundar C.                    NaN           115
# 6           Mari Selvaraj                    NaN           169
# 8            Rojin Thomas                    NaN           541
# 10                  Fazil              843373.49            53
# 11               Madhavan              398615.00          1100
# 13             Kiranraj K             7523995.00           392
# 14           Sibi Malayil              181001.00            33
# 15         Venkatesh Maha                    NaN           139
# 17       Sathyan Anthikad                    NaN            17
# 21          Sudha Kongara             1807228.92          2100
# 23       Mahesh Manjrekar                 633.00            72
# 27   Kadiri Venkata Reddy                    NaN            39
# 28       Sathyan Anthikad                    NaN            11
# 29              Bharathan                    NaN            26
# 31          T.J. Gnanavel                    NaN          3300
# 40       Vijay K. Bhaskar                    NaN            14
# 49              I.V. Sasi                    NaN            14
# 57                    Ram                3417.00           425
# 58           Priyadarshan                    NaN            14
# 71                Bhadran               62313.00            19
# 131          T. Hariharan              118072.29            45
#
#                        Awards  \
# 0    23 wins & 32 nominations
# 2               2 nominations
# 3       7 wins & 1 nomination
# 5      2 wins & 3 nominations
# 6     11 wins & 5 nominations
# 8      3 wins & 2 nominations
# 10                     5 wins
# 11    6 wins & 19 nominations
# 13     3 wins & 6 nominations
# 14                      1 win
# 15     2 wins & 6 nominations
# 17                     2 wins
# 21   23 wins & 24 nominations
# 23     2 wins & 5 nominations
# 27                        NaN
# 28                        NaN
# 29                    13 wins
# 31   10 wins & 20 nominations
# 40                      1 win
# 49                     2 wins
# 57     5 wins & 9 nominations
# 58                     2 wins
# 71                     4 wins
# 131                    6 wins
#
#                                            Description  \
# 0    The real-life story of IPS Officer Manoj Kumar...
# 2    A barber seeks vengeance after his home is bur...
# 3    A common man's struggles against a corrupt pol...
# 5    Two men, one young and arrogant, the other dam...
# 6    A law student from a lower caste begins a frie...
# 8    Oliver Twist (Indrans) wants to be tech-savvy ...
# 10   When a forbidden room in an old bungalow is un...
# 11   The story of Indian Space Research Organizatio...
# 13   Dharma is stuck in a rut with his negative and...
# 14   The life of a young man turns upside down when...
# 15   Four unconventional love stories set in the to...
# 17   A satire on contemporary Kerala politics where...
# 21   Nedumaaran Rajangam "Maara" sets out to make t...
# 23   After he retires, an aging theatre actor and h...
# 27   Balarama promises Subhadra to get his daughter...
# 28   After losing their jobs in Kerala, Dasan and V...
# 29   The urbane son of a village chieftain struggle...
# 31   When a tribal man is arrested for a case of al...
# 40   Venkateswarlu, aka Venky, comes Hyderabad to h...
# 49   Neelakandan squanders away the inheritance lef...
# 57   A single father tries to raise his daughter, w...
# 58   A woman hires a stranger to pose as her husban...
# 71   A small-town criminal constantly clashes with ...
# 131  The film offers an alternative version of the ...
#
#               Streaming platform
# 0                        SonyLIV
# 2                        Netflix
# 3    Amazon Prime Video, YouTube
# 5                Disney+ Hotstar
# 6             Amazon Prime Video
# 8             Amazon Prime Video
# 10               Disney+ Hotstar
# 11            Amazon Prime Video
# 13      Voot, Amazon Prime Video
# 14            Amazon Prime Video
# 15                       Netflix
# 17            Amazon Prime Video
# 21            Amazon Prime Video
# 23                          Zee5
# 27   Amazon Prime Video, YouTube
# 28   Amazon Prime Video, YouTube
# 29   Amazon Prime Video, YouTube
# 31            Amazon Prime Video
# 40            Amazon Prime Video
# 49   Amazon Prime Video, YouTube
# 57            Amazon Prime Video
# 58            Amazon Prime Video
# 71            Amazon Prime Video
# 131           Amazon Prime Video

# %% [markdown]
# Other data transformations

# %%
# Create a new column for calculating weighted review the multiplication of user review and rating
df_cleaned['weighted reviews'] = (df_cleaned['User reviews']* df_cleaned['Rating'])
df_cleaned.head()
# Out:
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
# 7          3 Idiots             2009  2 hours 50 minutes     8.4    441K
#
#        Film Industry             Genre             Director  \
# 0  Bollywood (Hindi)  Drama, Biography   Vidhu Vinod Chopra
# 2  Kollywood (Tamil)      Crime, Drama  Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama          Mani Ratnam
# 4     Bengali Cinema             Drama         Satyajit Ray
# 7  Bollywood (Hindi)     Comedy, Drama      Rajkumar Hirani
#
#    Box office collection  User reviews                        Awards  \
# 0              138288.00           945      23 wins & 32 nominations
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total
# 7            60262836.00          1000      64 wins & 30 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
# 7  Two friends are searching for their long lost ...
#
#             Streaming platform  weighted reviews
# 0                      SonyLIV            8410.5
# 2                      Netflix            3182.0
# 3  Amazon Prime Video, YouTube            2061.9
# 4  Amazon Prime Video, Hoichoi             520.8
# 7  Netflix, Amazon Prime Video            8400.0

# %%
# convert the Ratedby from string to integer datatype and add a new column
def convert_k_to_int(value):
    value = value.strip()  # Remove any leading/trailing whitespace
    if 'K' in value:
        return int(float(value.replace('K', '')) * 1000)  # Convert 'K' to integer
    else:
        return int(float(value))  # Handle numeric values without 'K'

# Apply the function and add as a new column
df_cleaned['Ratedby_converted'] = df_cleaned['Ratedby'].apply(convert_k_to_int)
df_cleaned.head()
# Out:
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
# 7          3 Idiots             2009  2 hours 50 minutes     8.4    441K
#
#        Film Industry             Genre             Director  \
# 0  Bollywood (Hindi)  Drama, Biography   Vidhu Vinod Chopra
# 2  Kollywood (Tamil)      Crime, Drama  Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama          Mani Ratnam
# 4     Bengali Cinema             Drama         Satyajit Ray
# 7  Bollywood (Hindi)     Comedy, Drama      Rajkumar Hirani
#
#    Box office collection  User reviews                        Awards  \
# 0              138288.00           945      23 wins & 32 nominations
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total
# 7            60262836.00          1000      64 wins & 30 nominations
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
# 7  Two friends are searching for their long lost ...
#
#             Streaming platform  weighted reviews  Ratedby_converted
# 0                      SonyLIV            8410.5             126000
# 2                      Netflix            3182.0              37000
# 3  Amazon Prime Video, YouTube            2061.9              25000
# 4  Amazon Prime Video, Hoichoi             520.8              17000
# 7  Netflix, Amazon Prime Video            8400.0             441000

# %%
# Generate a summary of the rating for different Film Industry
Film_Industry_summary_rating = df_cleaned.groupby('Film Industry')['Rating'].mean().reset_index()
print(Film_Industry_summary_rating)
# Out:
#            Film Industry    Rating
# 0         Bengali Cinema  8.175000
# 1      Bollywood (Hindi)  8.055696
# 2    Hollywood (English)  8.000000
# 3      Kollywood (Tamil)  8.255769
# 4         Marathi Cinema  8.800000
# 5  Mollywood (Malayalam)  8.225000
# 6   Sandalwood (Kannada)  8.300000
# 7     Tollywood (Telugu)  8.140000

# %%
# Create a new column (e.g., SuperHit, Hit, Flop)
df_cleaned['Popularity'] = pd.cut(df_cleaned['Rating'], bins=[0, 8, 8.5, np.inf], labels=['Flop', 'Hit' ,'SuperHit'])
df_cleaned.sample(10)
# Out:
#                             Movie name  Year of release         Watch  hour  \
# 7                             3 Idiots             2009  2 hours 50 minutes
# 137                              Lucia             2013  2 hours 15 minutes
# 142                         Special 26             2013  2 hours 24 minutes
# 167  Saptha Sagaradaache Ello - Side A             2023  2 hours 22 minutes
# 51                  Gangs of Wasseypur             2012  5 hours 21 minutes
# 207                           Super 30             2019  2 hours 34 minutes
# 4                     The World of Apu             1959   1 hour 45 minutes
# 16                 Like Stars on Earth             2007  2 hours 42 minutes
# 99                           Virumandi             2004  2 hours 55 minutes
# 179                   Deiva Thirumagal             2011  2 hours 46 minutes
#
#      Rating Ratedby         Film Industry                    Genre  \
# 7       8.4    441K     Bollywood (Hindi)            Comedy, Drama
# 137     8.3     13K  Sandalwood (Kannada)   Psychological Thriller
# 142     8.0     60K     Bollywood (Hindi)   Crime, Drama, Thriller
# 167     8.2    7.7K  Sandalwood (Kannada)           Drama, Romance
# 51      8.2    105K     Bollywood (Hindi)     Crime, Drama, Action
# 207     7.9     38K     Bollywood (Hindi)         Biography, Drama
# 4       8.4     17K        Bengali Cinema                    Drama
# 16      8.3    209K     Bollywood (Hindi)            Drama, Family
# 99      8.4      8K     Kollywood (Tamil)  Action, Drama, Thriller
# 179     8.2    6.6K     Kollywood (Tamil)            Drama, Family
#
#             Director  Box office collection  User reviews  \
# 7    Rajkumar Hirani            60262836.00          1000
# 137      Pawan Kumar               61445.78           129
# 142    Neeraj Pandey              647074.00           148
# 167   Hemanth M. Rao               37253.00            88
# 51    Anurag Kashyap             4384642.00           306
# 207       Vikas Bahl            24701637.00           617
# 4       Satyajit Ray              134241.00            62
# 16        Aamir Khan            21897373.00           463
# 99      Kamal Haasan             5746385.54            39
# 179       A.L. Vijay              846407.00            49
#
#                            Awards  \
# 7        64 wins & 30 nominations
# 137        4 wins & 3 nominations
# 142                13 nominations
# 167        6 wins & 9 nominations
# 51       18 wins & 65 nominations
# 207       6 wins & 12 nominations
# 4    4 wins & 2 nominations total
# 16       28 wins & 18 nominations
# 99                          1 win
# 179      13 wins & 13 nominations
#
#                                            Description  \
# 7    Two friends are searching for their long lost ...
# 137  A man suffering from insomnia is tricked into ...
# 142  A gang of con-men rob prominent rich businessm...
# 167  Manu and Priya hail from a middle-class backgr...
# 51   A clash between Sultan and Shahid Khan leads t...
# 207  Based on the life of Patna-based mathematician...
# 4    This final installment in Satyajit Ray's Apu T...
# 16   An eight-year-old boy is thought to be a lazy ...
# 99   A temperamental farmer gets embroiled in a blo...
# 179  A man with disabilities fights for custody of ...
#
#               Streaming platform  weighted reviews  Ratedby_converted  \
# 7    Netflix, Amazon Prime Video            8400.0             441000
# 137           Amazon Prime Video            1070.7              13000
# 142                      Netflix            1184.0              60000
# 167           Amazon Prime Video             721.6               7700
# 51            Amazon Prime Video            2509.2             105000
# 207                         Zee5            4874.3              38000
# 4    Amazon Prime Video, Hoichoi             520.8              17000
# 16      Netflix, Disney+ Hotstar            3842.9             209000
# 99            Amazon Prime Video             327.6               8000
# 179           Amazon Prime Video             401.8               6600
#
#     Popularity
# 7          Hit
# 137        Hit
# 142       Flop
# 167        Hit
# 51         Hit
# 207       Flop
# 4          Hit
# 16         Hit
# 99         Hit
# 179        Hit

# %%
def clean_box_office(value):
    if value == 'NIL':
        return 0.0
    else:
        return value

# Apply the function to clean the 'Box office collection' column
df_cleaned['Box office collection'] = df_cleaned['Box office collection'].apply(clean_box_office)

# Now, summarize the box office collection for each Film Industry
Film_Industry_summary_collection = df_cleaned.groupby('Film Industry').agg({
    'Box office collection': 'sum',  # Sum the box office collections
    'Rating': 'mean'                 # Calculate the mean rating
}).reset_index()

# Display the result
print(Film_Industry_summary_collection)
# Out:
#            Film Industry  Box office collection    Rating
# 0         Bengali Cinema           4.070710e+05  8.175000
# 1      Bollywood (Hindi)           1.179970e+09  8.055696
# 2    Hollywood (English)           1.408538e+08  8.000000
# 3      Kollywood (Tamil)           8.832680e+07  8.255769
# 4         Marathi Cinema           6.330000e+02  8.800000
# 5  Mollywood (Malayalam)           5.774348e+07  8.225000
# 6   Sandalwood (Kannada)           1.059601e+08  8.300000
# 7     Tollywood (Telugu)           2.896626e+08  8.140000

# %% [markdown]
# ### **Step 6: Grouping and Aggregation**

# %% [markdown]
# **Group By Operations**

# %% [markdown]
# a. Group the movies by the Year column and calculate the average IMDB rating for each year.

# %%
avg_rating_per_year = df.groupby('Year of release')['Rating'].mean()
avg_rating_per_year
# Out:
# Year of release
# 1955    8.200000
# 1956    8.200000
# 1957    8.700000
# 1958    7.900000
# 1959    8.400000
# 1960    8.100000
# 1964    8.100000
# 1965    8.300000
# 1968    8.100000
# 1970    7.900000
# 1971    8.100000
# 1975    8.133333
# 1979    8.500000
# 1982    8.300000
# 1983    8.300000
# 1987    8.400000
# 1988    8.250000
# 1989    8.800000
# 1991    8.750000
# 1992    8.300000
# 1993    8.700000
# 1994    8.000000
# 1995    8.250000
# 1996    8.100000
# 1997    8.150000
# 1998    8.300000
# 1999    8.175000
# 2000    8.133333
# 2001    8.200000
# 2002    8.133333
# 2003    8.066667
# 2004    8.071429
# 2005    8.175000
# 2006    8.077778
# 2007    8.020000
# 2008    8.150000
# 2009    8.075000
# 2010    8.142857
# 2011    8.083333
# 2012    8.061538
# 2013    8.063636
# 2014    8.185714
# 2015    8.161538
# 2016    8.207143
# 2017    8.050000
# 2018    8.314286
# 2019    8.193750
# 2020    8.200000
# 2021    8.323077
# 2022    8.257143
# 2023    8.250000
# 2024    8.225000
# Name: Rating, dtype: float64

# %% [markdown]
# b. Group the data by Director and count the number of movies each director has in the top 250.

# %%
movies_per_director = df.groupby('Director')['Movie name'].count()
movies_per_director
# Out:
# Director
# A.L. Vijay              1
# A.R. Murugadoss         1
# Aamir Khan              1
# Abhinav Sunder Nayak    1
# Abhishek Pathak         1
#                        ..
# Vishal Bhardwaj         3
# Vishnuvardhan           1
# Vivek Agnihotri         1
# Yash Chopra             2
# Zoya Akhtar             2
# Name: Movie name, Length: 182, dtype: int64

# %% [markdown]
# c. Find the highest-rated movie for each year by grouping the data by Year and selecting the movie with the highest rating in each group.

# %%
highest_rated_movie_per_year = df.loc[df.groupby('Year of release')['Rating'].idxmax()]
highest_rated_movie_per_year
# Out:
#                      Movie name  Year of release         Watch  hour  Rating  \
# 43              Pather Panchali             1955   2 hours 5 minutes     8.2
# 38                    Aparajito             1956   1 hour 50 minutes     8.2
# 27                    Mayabazar             1957  3 hours 12 minutes     9.1
# 196              The Music Room             1958   1 hour 35 minutes     7.9
# 4              The World of Apu             1959   1 hour 45 minutes     8.4
# 138               Mughal-E-Azam             1960  3 hours 17 minutes     8.1
# 120                   Charulata             1964   1 hour 57 minutes     8.1
# 54                        Guide             1965   3 hours 3 minutes     8.3
# 154                     Padosan             1968  2 hours 37 minutes     8.1
# 221             Mera Naam Joker             1970  3 hours 44 minutes     7.9
# 128                       Anand             1971   2 hours 2 minutes     8.1
# 46                Chupke Chupke             1975  2 hours 26 minutes     8.3
# 1                      Gol Maal             1979            2 hours      8.5
# 92                       Angoor             1982  2 hours 11 minutes     8.3
# 36           Jaane Bhi Do Yaaro             1983  2 hours 12 minutes     8.3
# 28                 Nadodikkattu             1987  2 hours 38 minutes     8.8
# 58                     Chithram             1988  2 hours 39 minutes     8.6
# 14                     Kireedam             1989   2 hours 4 minutes     8.9
# 17                    Sandesham             1991  2 hours 18 minutes     9.0
# 29                 Thevar Magan             1992  2 hours 25 minutes     8.7
# 10            Manichithrathazhu             1993  2 hours 49 minutes     8.7
# 151             Andaz Apna Apna             1994  2 hours 40 minutes     8.0
# 71                     Spadikam             1995  2 hours 30 minutes     8.6
# 134                      Indian             1996   3 hours 5 minutes     8.1
# 60                       Iruvar             1997  2 hours 20 minutes     8.4
# 44                        Satya             1998  2 hours 50 minutes     8.3
# 63                    Mudhalvan             1999  2 hours 49 minutes     8.4
# 124               Alai Payuthey             2000  2 hours 36 minutes     8.3
# 40         Nuvvu Naaku Nachchav             2001   3 hours 4 minutes     8.8
# 65        Kannathil Muthamittal             2002  2 hours 16 minutes     8.3
# 5                    Anbe Sivam             2003  2 hours 40 minutes     8.6
# 9                  Black Friday             2004  2 hours 23 minutes     8.4
# 35                      Anniyan             2005     3 hours 1minute     8.3
# 85                 Pudhu Pettai             2006  2 hours 48 minutes     8.4
# 16          Like Stars on Earth             2007  2 hours 42 minutes     8.3
# 144            Vaaranam Aayiram             2008  2 hours 49 minutes     8.2
# 7                      3 Idiots             2009  2 hours 50 minutes     8.4
# 83              Aaranya Kaandam             2010   2 hours 6 minutes     8.5
# 59     Zindagi Na Milegi Dobara             2011  2 hours 35 minutes     8.2
# 51           Gangs of Wasseypur             2012  5 hours 21 minutes     8.2
# 34                     Drishyam             2013  2 hours 40 minutes     8.3
# 174         Ulidavaru Kandanthe             2014  2 hours 34 minutes     8.4
# 24                   Visaaranai             2015   1 hour 57 minutes     8.4
# 23                    Natsamrat             2016  2 hours 46 minutes     8.8
# 75                 Vikram Vedha             2017  2 hours 27 minutes     8.2
# 15            C/o Kancharapalem             2018  2 hours 32 minutes     8.8
# 12            Kumbalangi Nights             2019  2 hours 15 minutes     8.5
# 21              Soorarai Pottru             2020  2 hours 33 minutes     8.7
# 8                         #Home             2021  2 hours 38 minutes     8.8
# 11   Rocketry: The Nambi Effect             2022  2 hours 37 minutes     8.7
# 0                     12th Fail             2023  2 hours 27 minutes     8.9
# 2                      Maharaja             2024  2 hours 30 minutes     8.6
#
#     Ratedby          Film Industry                           Genre  \
# 43      39K         Bengali Cinema                           Drama
# 38      16K         Bengali Cinema                           Drama
# 27     5.9K     Tollywood (Telugu)           Fantasy, Mythological
# 196    6.8K         Bengali Cinema                           Drama
# 4       17K         Bengali Cinema                           Drama
# 138    8.9K      Bollywood (Hindi)             Historical, Romance
# 120    7.3K         Bengali Cinema                  Drama, Romance
# 54     8.7K      Bollywood (Hindi)                  Romance, Drama
# 154    7.6K      Bollywood (Hindi)                 Comedy, Romance
# 221    5.4K      Bollywood (Hindi)                  Drama, Musical
# 128     36K     Tollywood (Telugu)                  Romance, Drama
# 46      13K      Bollywood (Hindi)                          Comedy
# 1       20K      Bollywood (Hindi)                          Comedy
# 92     5.9K      Bollywood (Hindi)                          Comedy
# 36      15K      Bollywood (Hindi)                  Satire, Comedy
# 28     5.9K  Mollywood (Malayalam)        Satire, Comedy, Thriller
# 58     6.2K  Mollywood (Malayalam)                   Comedy, Drama
# 14     8.8K  Mollywood (Malayalam)                   Drama, Family
# 17     5.4K  Mollywood (Malayalam)        Political Satire, Comedy
# 29     8.2K      Kollywood (Tamil)                   Drama, Family
# 10      13K  Mollywood (Malayalam)         Horror, Thriller, Drama
# 151     56K      Bollywood (Hindi)                          Comedy
# 71       7K  Mollywood (Malayalam)                   Action, Drama
# 134     15K      Kollywood (Tamil)        Action, Drama, Vigilante
# 60     7.4K      Kollywood (Tamil)                Drama, Political
# 44      17K      Bollywood (Hindi)                    Crime, Drama
# 63     8.6K      Kollywood (Tamil)      Political Thriller, Action
# 124    7.5K      Kollywood (Tamil)                  Romance, Drama
# 40     5.7K     Tollywood (Telugu)                 Romance, Comedy
# 65     9.3K      Kollywood (Tamil)              Drama, War, Family
# 5       26K      Kollywood (Tamil)                   Drama, Comedy
# 9       22K      Bollywood (Hindi)          Crime, Drama, Thriller
# 35      22K      Kollywood (Tamil)  Action, Psychological Thriller
# 85     8.1K      Kollywood (Tamil)                    Crime, Drama
# 16     209K      Bollywood (Hindi)                   Drama, Family
# 144     15K      Kollywood (Tamil)                  Romance, Drama
# 7      441K      Bollywood (Hindi)                   Comedy, Drama
# 83     5.5K      Kollywood (Tamil)              Neo-noir, Thriller
# 59      87K      Bollywood (Hindi)                  Drama, Romance
# 51     105K      Bollywood (Hindi)            Crime, Drama, Action
# 34      45K  Mollywood (Malayalam)                 Thriller, Drama
# 174    9.6K   Sandalwood (Kannada)                    Crime, Drama
# 24      12K      Kollywood (Tamil)          Crime, Drama, Thriller
# 23     7.3K         Marathi Cinema                  Drama, Tragedy
# 75      51K      Kollywood (Tamil)         Action, Crime, Thriller
# 15     8.2K     Tollywood (Telugu)                Drama, Anthology
# 12      19K  Mollywood (Malayalam)                   Drama, Family
# 21     125K      Kollywood (Tamil)                Drama, Biography
# 8       16K  Mollywood (Malayalam)                   Drama, Family
# 11      59K      Bollywood (Hindi)                Biography, Drama
# 0      126K      Bollywood (Hindi)                Drama, Biography
# 2       37K      Kollywood (Tamil)                    Crime, Drama
#
#                    Director  Box office collection  User reviews  \
# 43             Satyajit Ray              135342.00           204
# 38             Satyajit Ray              134241.00            59
# 27     Kadiri Venkata Reddy                    NaN            39
# 196            Satyajit Ray                3247.00            42
# 4              Satyajit Ray              134241.00            62
# 138                 K. Asif              161434.00            46
# 120            Satyajit Ray                    NaN            43
# 54              Vijay Anand                    NaN            62
# 154           Jyoti Swaroop                    NaN            28
# 221              Raj Kapoor                    NaN            29
# 128    Hrishikesh Mukherjee               36144.58           152
# 46     Hrishikesh Mukherjee               11939.76            22
# 1      Hrishikesh Mukherjee                    NaN            48
# 92                   Gulzar                    NaN            24
# 36              Kundan Shah                    NaN            62
# 28         Sathyan Anthikad                    NaN            11
# 58             Priyadarshan                    NaN            14
# 14             Sibi Malayil              181001.00            33
# 17         Sathyan Anthikad                    NaN            17
# 29                Bharathan                    NaN            26
# 10                    Fazil              843373.49            53
# 151       Rajkumar Santoshi                    NaN           138
# 71                  Bhadran               62313.00            19
# 134              S. Shankar                 184.00            27
# 60              Mani Ratnam                    NaN            36
# 44          Ram Gopal Varma                    NaN            77
# 63               S. Shankar             6024096.39            14
# 124             Mani Ratnam             4216867.47            28
# 40         Vijay K. Bhaskar                    NaN            14
# 65              Mani Ratnam                    NaN            49
# 5                 Sundar C.                    NaN           115
# 9            Anurag Kashyap             1610897.00            88
# 35               S. Shankar             3373493.98            74
# 85         K. Selvaraghavan                4652.00            37
# 16               Aamir Khan            21897373.00           463
# 144   Gautham Vasudev Menon              921007.00            59
# 7           Rajkumar Hirani            60262836.00          1000
# 83   Thiagarajan Kumararaja              843373.49            25
# 59              Zoya Akhtar             5192743.00           240
# 51           Anurag Kashyap             4384642.00           306
# 34            Jeethu Joseph            13076265.00           141
# 174          Rakshit Shetty              253012.05            72
# 24              Vetrimaaran                1943.00            47
# 23         Mahesh Manjrekar                 633.00            72
# 75                  Gayatri              546792.00           208
# 15           Venkatesh Maha                    NaN           139
# 12       Madhu C. Narayanan             1312005.00           194
# 21            Sudha Kongara             1807228.92          2100
# 8              Rojin Thomas                    NaN           541
# 11                 Madhavan              398615.00          1100
# 0        Vidhu Vinod Chopra              138288.00           945
# 2       Nithilan Saminathan              975543.00           370
#
#                             Awards  \
# 43   11 wins & 2 nominations total
# 38    6 wins & 2 nominations total
# 27                             NaN
# 196         2 wins & 2 nominations
# 4     4 wins & 2 nominations total
# 138         3 wins & 3 nominations
# 120         8 wins & 2 nominations
# 54          9 wins & 3 nominations
# 154                            NaN
# 221                        11 wins
# 128          9 wins & 1 nomination
# 46                             NaN
# 1            3 wins & 1 nomination
# 92            1 win & 1 nomination
# 36          2 wins & 3 nominations
# 28                             NaN
# 58                          2 wins
# 14                           1 win
# 17                          2 wins
# 29                         13 wins
# 10                          5 wins
# 151                  4 nominations
# 71                          4 wins
# 134                         9 wins
# 60           3 wins & 1 nomination
# 44         12 wins & 6 nominations
# 63          3 wins & 2 nominations
# 124                         4 wins
# 40                           1 win
# 65         18 wins & 2 nominations
# 5           2 wins & 3 nominations
# 9            1 win & 7 nominations
# 35                         18 wins
# 85                           1 win
# 16        28 wins & 18 nominations
# 144       22 wins & 18 nominations
# 7         64 wins & 30 nominations
# 83          3 wins & 6 nominations
# 59        35 wins & 38 nominations
# 51        18 wins & 65 nominations
# 34         16 wins & 6 nominations
# 174        4 wins & 10 nominations
# 24         11 wins & 7 nominations
# 23          2 wins & 5 nominations
# 75        12 wins & 13 nominations
# 15          2 wins & 6 nominations
# 12        13 wins & 11 nominations
# 21        23 wins & 24 nominations
# 8           3 wins & 2 nominations
# 11         6 wins & 19 nominations
# 0         23 wins & 32 nominations
# 2                    2 nominations
#
#                                            Description  \
# 43   Impoverished priest Harihar Ray, dreaming of a...
# 38   Following his father's death, a boy leaves hom...
# 27   Balarama promises Subhadra to get his daughter...
# 196  Depicts the end days of a decadent zamindar (l...
# 4    This final installment in Satyajit Ray's Apu T...
# 138  A 16th century prince falls in love with a cou...
# 120  The lonely wife of a newspaper editor falls in...
# 54   When mistaken to be a sage by some villagers, ...
# 154  A simple man from a village falls in love with...
# 221  Raju is a joker, a clown. It is what he is and...
# 128  The story of a terminally ill man who wishes t...
# 46   A newly wedded husband plays a practical joke ...
# 1    A man's simple lie to secure his job escalates...
# 92   Based on Shakespeare's 'A Comedy of Errors', t...
# 36   Two photographers, who are employed by a magaz...
# 28   After losing their jobs in Kerala, Dasan and V...
# 58   A woman hires a stranger to pose as her husban...
# 14   The life of a young man turns upside down when...
# 17   A satire on contemporary Kerala politics where...
# 29   The urbane son of a village chieftain struggle...
# 10   When a forbidden room in an old bungalow is un...
# 151  Two slackers competing for the affections of a...
# 71   A small-town criminal constantly clashes with ...
# 134  A veteran freedom fighter enraged with the ris...
# 60   A struggling actor and a writer-politician bec...
# 44   An innocent man is embroiled in underworld aft...
# 63   A man accepts a challenge to act as the Chief ...
# 124  After a difficult romance in a class-divided s...
# 40   Venkateswarlu, aka Venky, comes Hyderabad to h...
# 65   A little girl is told by her parents that she ...
# 5    Two men, one young and arrogant, the other dam...
# 9    A film about the investigations following the ...
# 35   Ramanujam, who suffers from multiple personali...
# 85   After running away from his home, Kumar falls ...
# 16   An eight-year-old boy is thought to be a lazy ...
# 144  A father and son help each other through growi...
# 7    Two friends are searching for their long lost ...
# 83   A mob boss must deal with a disgruntled mistre...
# 59   Three friends decide to turn their fantasy vac...
# 51   A clash between Sultan and Shahid Khan leads t...
# 34   A man goes to extreme lengths to save his fami...
# 174  A journalist sets out to uncover the truth beh...
# 24   Four labourers are tortured by the police to c...
# 23   After he retires, an aging theatre actor and h...
# 75   Vikram, a no-nonsense police officer, accompan...
# 15   Four unconventional love stories set in the to...
# 12   The film revolves around four brothers who sha...
# 21   Nedumaaran Rajangam "Maara" sets out to make t...
# 8    Oliver Twist (Indrans) wants to be tech-savvy ...
# 11   The story of Indian Space Research Organizatio...
# 0    The real-life story of IPS Officer Manoj Kumar...
# 2    A barber seeks vengeance after his home is bur...
#
#                     Streaming platform
# 43         Amazon Prime Video, Hoichoi
# 38                  Amazon Prime Video
# 27         Amazon Prime Video, YouTube
# 196                 Amazon Prime Video
# 4          Amazon Prime Video, Hoichoi
# 138                 Amazon Prime Video
# 120                 Amazon Prime Video
# 54         Amazon Prime Video, YouTube
# 154        Amazon Prime Video, YouTube
# 221                 Amazon Prime Video
# 128                 Amazon Prime Video
# 46         Amazon Prime Video, YouTube
# 1    Amazon Prime Video, YouTube, Zee5
# 92                  Amazon Prime Video
# 36                             YouTube
# 28         Amazon Prime Video, YouTube
# 58                  Amazon Prime Video
# 14                  Amazon Prime Video
# 17                  Amazon Prime Video
# 29         Amazon Prime Video, YouTube
# 10                     Disney+ Hotstar
# 151        Amazon Prime Video, YouTube
# 71                  Amazon Prime Video
# 134                 Amazon Prime Video
# 60                  Amazon Prime Video
# 44                  Amazon Prime Video
# 63                  Amazon Prime Video
# 124                 Amazon Prime Video
# 40                  Amazon Prime Video
# 65                  Amazon Prime Video
# 5                      Disney+ Hotstar
# 9                              YouTube
# 35                  Amazon Prime Video
# 85                  Amazon Prime Video
# 16            Netflix, Disney+ Hotstar
# 144                 Amazon Prime Video
# 7          Netflix, Amazon Prime Video
# 83                  Amazon Prime Video
# 59         Netflix, Amazon Prime Video
# 51                  Amazon Prime Video
# 34                  Amazon Prime Video
# 174                               Voot
# 24                             Netflix
# 23                                Zee5
# 75                     Disney+ Hotstar
# 15                             Netflix
# 12                  Amazon Prime Video
# 21                  Amazon Prime Video
# 8                   Amazon Prime Video
# 11                  Amazon Prime Video
# 0                              SonyLIV
# 2                              Netflix

# %% [markdown]
# Other grouping and aggregation operations

# %%
# Average of Rating by Film Industry and Genre
Film_Industry_Genre_summary = df_cleaned.groupby(['Film Industry', 'Genre']).agg({
    'Ratedby_converted': 'mean'
}).reset_index()

print(Film_Industry_Genre_summary)
# Out:
#           Film Industry                     Genre  Ratedby_converted
# 0        Bengali Cinema                     Drama            19700.0
# 1     Bollywood (Hindi)          Action, Thriller            61000.0
# 2     Bollywood (Hindi)   Action, Thriller, Drama            27000.0
# 3     Bollywood (Hindi)          Biography, Drama            39000.0
# 4     Bollywood (Hindi)  Biography, Drama, Social            29000.0
# ..                  ...                       ...                ...
# 120  Tollywood (Telugu)           Political Drama             5700.0
# 121  Tollywood (Telugu)    Romance, Comedy, Drama             8500.0
# 122  Tollywood (Telugu)            Romance, Drama            45000.0
# 123  Tollywood (Telugu)             Sports, Drama            23000.0
# 124  Tollywood (Telugu)         Thriller, Mystery             6800.0
#
# [125 rows x 3 columns]

# %%
# Advance Data Manipulation
# Pivot Table to summarize data by Film Industry and Popularity
pivot_table = df_cleaned.pivot_table(values='Box office collection', index='Film Industry', columns='Popularity', aggfunc='sum')

print(pivot_table)
# Out:
# Popularity                     Flop           Hit    SuperHit
# Film Industry
# Bengali Cinema         3.247000e+03  4.038240e+05        0.00
# Bollywood (Hindi)      3.648356e+08  8.145978e+08   536903.00
# Hollywood (English)    1.408538e+08  0.000000e+00        0.00
# Kollywood (Tamil)      1.169611e+07  7.360595e+07  3024743.14
# Marathi Cinema         0.000000e+00  0.000000e+00      633.00
# Mollywood (Malayalam)  1.057260e+07  4.608420e+07  1086687.49
# Sandalwood (Kannada)   0.000000e+00  9.843615e+07  7523995.00
# Tollywood (Telugu)     2.676218e+07  2.629004e+08        0.00
# <ipython-input-30-b2cf2dbd55b7>:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df_cleaned.pivot_table(values='Box office collection', index='Film Industry', columns='Popularity', aggfunc='sum')

# %% [markdown]
# **Column Creation and Manipulation**

# %% [markdown]
# a. Create a new column named Rating Category that categorizes movies as "Excellent" if the IMDB rating is 9.0 or above, "Good" if between 8.0 and 9.0, and "Average" if below 8.0.

# %%
def categorize_rating(rating):
    if rating >= 9.0:
        return 'Excellent'
    elif 8.0 <= rating < 9.0:
        return 'Good'
    else:
        return 'Average'

df['Rating Category'] = df['Rating'].apply(categorize_rating)

# %% [markdown]
# b. Extract the Year from the movie title (assuming the year is part of the title) and create a new column Extracted Year.

# %%
df['Extracted Year'] = df['Movie name'].str.extract(r'\((\d{4})\)').astype(float)

# %% [markdown]
# c. Create a new column that combines the Title and Director into a single string, separated by a hyphen.

# %%
df['Title-Director'] = df['Movie name'] + ' - ' + df['Director']

# %%
# Display the DataFrame to see the new columns
df[['Movie name', 'Rating', 'Rating Category', 'Extracted Year', 'Title-Director']]
# Out:
#                    Movie name  Rating Rating Category  Extracted Year  \
# 0                   12th Fail     8.9            Good             NaN
# 1                    Gol Maal     8.5            Good             NaN
# 2                    Maharaja     8.6            Good             NaN
# 3                     Nayakan     8.7            Good             NaN
# 4            The World of Apu     8.4            Good             NaN
# ..                        ...     ...             ...             ...
# 245                 Mr. India     7.7         Average             NaN
# 246  Hazaaron Khwaishein Aisi     7.9         Average             NaN
# 247                    Ghilli     8.1            Good             NaN
# 248  Mukundan Unni Associates     7.9         Average             NaN
# 249                Happy Days     7.9         Average             NaN
#
#                                       Title-Director
# 0                     12th Fail - Vidhu Vinod Chopra
# 1                    Gol Maal - Hrishikesh Mukherjee
# 2                     Maharaja - Nithilan Saminathan
# 3                              Nayakan - Mani Ratnam
# 4                    The World of Apu - Satyajit Ray
# ..                                               ...
# 245                        Mr. India - Shekhar Kapur
# 246         Hazaaron Khwaishein Aisi - Sudhir Mishra
# 247                                 Ghilli - Dharani
# 248  Mukundan Unni Associates - Abhinav Sunder Nayak
# 249                      Happy Days - Sekhar Kammula
#
# [250 rows x 5 columns]

# %% [markdown]
# # **Alternative ways to fill missing values**

# %% [markdown]
# # **Loading the data**

# %%
nfl_data = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Exploratory_Data_Analysis/Dataset/IMdB_India_Top250.csv")

# %%
nfl_data.head()
# Out:
#          Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#   Box office collection  User reviews                        Awards  \
# 0           $138,288.00           945      23 wins & 32 nominations
# 1                   NIL            48         3 wins & 1 nomination
# 2           $975,543.00           370                 2 nominations
# 3           $120,481.93           237         7 wins & 1 nomination
# 4           $134,241.00            62  4 wins & 2 nominations total
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi

# %% [markdown]
# Replace missing values or NIL or 0 with NaN or None

# %%
# Strip whitespace from column names
nfl_data.columns = nfl_data.columns.str.strip()
# Print columns to verify the correct name
print(nfl_data.columns)

# Replace "NIL" with NaN in the entire DataFrame
nfl_data.replace("NIL", np.nan, inplace=True)

# Replace "NIL" with NaN in the 'Box Office Collection' column specifically
nfl_data['Box office collection'].replace("NIL", np.nan, inplace=True)
# Out:
# Index(['Movie name', 'Year of release', 'Watch  hour', 'Rating', 'Ratedby',
#        'Film Industry', 'Genre', 'Director', 'Box office collection',
#        'User reviews', 'Awards', 'Description', 'Streaming platform'],
#       dtype='object')
# <ipython-input-37-49efe66e37f3>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nfl_data['Box office collection'].replace("NIL", np.nan, inplace=True)

# %%
# Function to clean the 'Box office collection' column
def clean_box_office(value):
    value = value.strip()  # Remove leading/trailing spaces
    if value == 'NIL' or value == '$0' or value == '$0.00':
        return 0.0
    else:
        # Remove $ and commas, then convert to float
        return float(value.replace('$', '').replace(',', ''))

# Apply the function to clean the 'Box office collection' column
nfl_data['Box office collection'] = nfl_data['Box office collection'].apply(clean_box_office)

# Replace 0.0 with NaN in the 'Box office collection' column
nfl_data['Box office collection'].replace(0.0, np.nan, inplace=True)

# Print the result to verify
nfl_data.head()
# Out:
# <ipython-input-38-8e4792ef7118>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nfl_data['Box office collection'].replace(0.0, np.nan, inplace=True)
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards  \
# 0              138288.00           945      23 wins & 32 nominations
# 1                    NaN            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi

# %% [markdown]
# By looking at the data, it can be seen that missing column has information on the Box office collection and award. This means that column with Box office collection values are probably missing because they were not recorded, rather than because they don't exist. So, it would make sense for us to try and guess what they should be rather than just leaving them as NA's.
#
# On the other hand, there is column of awards, also have lot of missing fields. In this case, though, the field is missing because if there was no award then it doesn't make sense to guess it . For this column, it would make more sense to either leave it empty or to add a third value like "neither" and use that to replace the NA's.

# %% [markdown]
# # Drop missing values
# If you're in a hurry or don't have a reason to figure out why your values are missing, one option you have is to just remove any rows or columns that contain missing values.

# %%
nfl_data_copy = nfl_data.copy()
# remove all the rows that contain a missing value
nfl_data_copy.dropna()
# Out:
#                    Movie name  Year of release         Watch  hour  Rating  \
# 0                   12th Fail             2023  2 hours 27 minutes     8.9
# 2                    Maharaja             2024  2 hours 30 minutes     8.6
# 3                     Nayakan             1987  2 hours 25 minutes     8.7
# 4            The World of Apu             1959   1 hour 45 minutes     8.4
# 7                    3 Idiots             2009  2 hours 50 minutes     8.4
# ..                        ...              ...                 ...     ...
# 243               Vicky Donor             2012   2 hours 6 minutes     7.7
# 244          Angamaly Diaries             2017  2 hours 12 minutes     7.9
# 247                    Ghilli             2004  2 hours 40 minutes     8.1
# 248  Mukundan Unni Associates             2022   2 hours 8 minutes     7.9
# 249                Happy Days             2007  2 hours 33 minutes     7.9
#
#     Ratedby          Film Industry                   Genre  \
# 0      126K      Bollywood (Hindi)        Drama, Biography
# 2       37K      Kollywood (Tamil)            Crime, Drama
# 3       25K      Kollywood (Tamil)            Crime, Drama
# 4       17K         Bengali Cinema                   Drama
# 7      441K      Bollywood (Hindi)           Comedy, Drama
# ..      ...                    ...                     ...
# 243     46K      Bollywood (Hindi)           Comedy, Drama
# 244    6.8K  Mollywood (Malayalam)            Crime, Drama
# 247     17K      Kollywood (Tamil)           Action, Drama
# 248    6.2K  Mollywood (Malayalam)           Satire, Drama
# 249    6.3K     Tollywood (Telugu)  Drama, Romance, Comedy
#
#                  Director  Box office collection  User reviews  \
# 0      Vidhu Vinod Chopra              138288.00           945
# 2     Nithilan Saminathan              975543.00           370
# 3             Mani Ratnam              120481.93           237
# 4            Satyajit Ray              134241.00            62
# 7         Rajkumar Hirani            60262836.00          1000
# ..                    ...                    ...           ...
# 243        Shoojit Sircar             6456358.00            82
# 244  Lijo Jose Pellissery              661915.00            39
# 247               Dharani              163961.00            47
# 248  Abhinav Sunder Nayak               44990.00            62
# 249        Sekhar Kammula              361445.78            16
#
#                            Awards  \
# 0        23 wins & 32 nominations
# 2                   2 nominations
# 3           7 wins & 1 nomination
# 4    4 wins & 2 nominations total
# 7        64 wins & 30 nominations
# ..                            ...
# 243      43 wins & 37 nominations
# 244        2 wins & 6 nominations
# 247        2 wins & 2 nominations
# 248                         1 win
# 249                        7 wins
#
#                                            Description  \
# 0    The real-life story of IPS Officer Manoj Kumar...
# 2    A barber seeks vengeance after his home is bur...
# 3    A common man's struggles against a corrupt pol...
# 4    This final installment in Satyajit Ray's Apu T...
# 7    Two friends are searching for their long lost ...
# ..                                                 ...
# 243  A man is brought in by an infertility doctor t...
# 244  Vincent Pepe who wanted to be a powerful leade...
# 247  Velu, an aspiring kabaddi player, goes to Madu...
# 248  Advocate Mukundan Unni, played by Vineeth Sree...
# 249  A group of eight youngsters from an engineerin...
#
#               Streaming platform
# 0                        SonyLIV
# 2                        Netflix
# 3    Amazon Prime Video, YouTube
# 4    Amazon Prime Video, Hoichoi
# 7    Netflix, Amazon Prime Video
# ..                           ...
# 243  Amazon Prime Video, Netflix
# 244                      Netflix
# 247              Disney+ Hotstar
# 248              Disney+ Hotstar
# 249           Amazon Prime Video
#
# [194 rows x 13 columns]

# %% [markdown]
# **Removing all the columns that have at least one missing value instead**

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = nfl_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  User reviews  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra           945
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee            48
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan           370
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam           237
# 4     Bengali Cinema             Drama          Satyajit Ray            62
#
#                                          Description  \
# 0  The real-life story of IPS Officer Manoj Kumar...
# 1  A man's simple lie to secure his job escalates...
# 2  A barber seeks vengeance after his home is bur...
# 3  A common man's struggles against a corrupt pol...
# 4  This final installment in Satyajit Ray's Apu T...
#
#                   Streaming platform
# 0                            SonyLIV
# 1  Amazon Prime Video, YouTube, Zee5
# 2                            Netflix
# 3        Amazon Prime Video, YouTube
# 4        Amazon Prime Video, Hoichoi

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % nfl_data.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 13
#
# Columns with na's dropped: 11

# %% [markdown]
# # Filling in missing values automatically
#
# Another option is to try and fill in the missing values. For this next bit, we take a small sub-section of the NFL data so that it will print well.

# %%
# get a small subset of the NFL dataset
subset_nfl_data = nfl_data.loc[:, 'Movie name':'Awards'].head()
subset_nfl_data
# Out:
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards
# 0              138288.00           945      23 wins & 32 nominations
# 1                    NaN            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total

# %% [markdown]
# **Filling missing value with 0.**

# %%
# replace all NA's with 0
subset_nfl_data.fillna(0)
# Out:
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards
# 0              138288.00           945      23 wins & 32 nominations
# 1                   0.00            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total

# %% [markdown]
# **Filling missing value with backward-filling in column for first value and then filling all missing values with 0 after first value.**

# %%
# replace all NA's the value that comes directly after it in the same column,
# then replace all the reamining na's with 0
subset_nfl_data.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
# <ipython-input-44-02d49a0b06ce>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_nfl_data.fillna(method = 'bfill', axis=0).fillna(0)
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards
# 0              138288.00           945      23 wins & 32 nominations
# 1              975543.00            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total

# %% [markdown]
# **Filling missing value with backward-filling in column.**

# %%
subset_nfl_data.fillna(method = 'bfill', axis=0)
# Out:
# <ipython-input-45-1ff915e96120>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_nfl_data.fillna(method = 'bfill', axis=0)
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards
# 0              138288.00           945      23 wins & 32 nominations
# 1              975543.00            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total

# %% [markdown]
# **Filling missing value with forward-filling in column.**

# %%
subset_nfl_data.fillna(method = 'ffill', axis=0)
# Out:
# <ipython-input-46-373d639591a1>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_nfl_data.fillna(method = 'ffill', axis=0)
#          Movie name  Year of release         Watch  hour  Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#    Box office collection  User reviews                        Awards
# 0              138288.00           945      23 wins & 32 nominations
# 1              138288.00            48         3 wins & 1 nomination
# 2              975543.00           370                 2 nominations
# 3              120481.93           237         7 wins & 1 nomination
# 4              134241.00            62  4 wins & 2 nominations total
