# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get("https://tfrrs.org/")

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html class="no-js js-menubar" lang="en">\n<head>\n<!-- Google tag (gtag.js) -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-0Z9Z2N6ZD0"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'G-0Z9Z2N6ZD0\');\n</script>\n\n<!-- Google Analytics -->\n<script>\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\nm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n})(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\nga(\'create\', \'UA-66287-6\', \'auto\');  \nga(\'send\', \'pageview\');\n\n</script>\n<!-- End Google Analytics -->\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, 
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js js-menubar" lang="en">
#  <head>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-0Z9Z2N6ZD0">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-0Z9Z2N6ZD0');
#   </script>
#   <!-- Google Analytics -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-66287-6', 'auto');
# ga('send', 'pageview');
#   </script>
#   <!-- End Google Analytics -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# ...

# %%
# Pull all meetname from the table
meet_name = soup.find_all(class_="tablesaw")
print(meet_name_list)
# Out:
# [<table class="tablesaw tablesaw-xc table-striped table-bordered table-hover" data-tablesaw-mode="columntoggle">
# <thead>
# <tr>
# <th data-tablesaw-priority="persist" scope="col">DATE
#     </th>
# <th scope="col">MEET NAME</th>
# <th data-tablesaw-priority="1" scope="col">STATE</th>
# <th data-tablesaw-priority="2" scope="col">VENUE</th>
# </tr>
# </thead>
# <tbody id="results_page1">
# <tr>
# <td>Sep 21-22</td>
# <td><a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23637/YSU_NCAA_Collegiate_Inaugural_Alumni_Cross_Country_Meet">YSU NCAA Collegiate Inaugural Alumni Cross Country Meet</a>
# </td>
# <td>OH</td>
# <td>Mill Creek</td>
# </tr>
# <tr>
# <td>Sep 21</td>
# <td><a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23355/Hoffmann_Invitational___Liberty_League_Preview">Hoffmann Invitational / Liberty League Preview</a>
# </td>
# <td>NY</td>
# <td>St. Lawrence</td>
# </tr>
# <tr>
# <td>Sep 21</td>
# ...
