# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# Fetch the webpage
response = requests.get('https://www.tfrrs.org/')
print(response)

# Parse the content of the page
parsed_content = BeautifulSoup(response.text, 'html.parser')
print(parsed_content.prettify())

# Locate the specific table of interest
panel_content = parsed_content.find(class_="panel panel-bordered")
print(panel_content.prettify())

# Extract the actual table from the panel content
target_table = panel_content.find("table")
print(target_table.prettify())

# Retrieve headers from the table
header_elements = target_table.find_all('th')
header_names = [header.get_text(strip=True) for header in header_elements]

# Extract the data from each row in the table
records = []
for table_row in target_table.find_all('tr')[1:]:
    cells = table_row.find_all('td')
    if cells:
        date_event = cells[0].get_text(strip=True)
        event_name = cells[1].get_text(strip=True)
        state_info = cells[2].get_text(strip=True)
        venue_info = cells[3].get_text(strip=True)

        # Extract the hyperlink from the second cell
        link_element = cells[1].find('a')
        event_link = link_element['href'] if link_element else ''

        records.append([date_event, event_name, state_info, venue_info, event_link])

# Define the name of the output CSV file
output_csv = 'cross_country_events.csv'

# Write data to the CSV file
with open(output_csv, mode='w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write header with the additional link column
    csv_writer.writerow(header_names + ["Event Link"])

    # Write the data records
    csv_writer.writerows(records)

print(f'Data successfully saved to {output_csv}')
data_frame = pd.read_csv('cross_country_events.csv')
print(data_frame)

# Function to normalize the event links
def normalize_link(link):
    if not link.startswith("https://www.tfrrs.org/"):
        return "https://www.tfrrs.org/" + link
    return link

# Function to fetch and extract tables from a given URL
def extract_tables(page_url):
    page_response = requests.get(page_url)
    page_soup = BeautifulSoup(page_response.text, 'html.parser')

    # Locate all tables in the page
    all_tables = page_soup.find_all('table')

    # Convert tables to DataFrames
    data_frames = []
    for table in all_tables:
        data_frames.append(pd.read_html(str(table))[0])

    return data_frames

# Function to save DataFrames to CSV files
def export_tables_to_csv(data_frames, event_title):
    for idx, frame in enumerate(data_frames):
        file_name = f"{event_title}_table_{idx + 1}.csv"
        frame.to_csv(file_name, index=False)
        print(f"File saved: {file_name}")

# Apply the link normalization function
data_frame['Complete Link'] = data_frame['Event Link'].apply(normalize_link)

# Process each link and save the associated tables
for idx, record in data_frame.iterrows():
    try:
        event_url = record['Complete Link']
        sanitized_title = record['MEET NAME'].replace('/', '_')  # Clean title for filename
        tables = extract_tables(event_url)
        export_tables_to_csv(tables, sanitized_title)
    except Exception as error:
        print(f"Error processing {event_url}: {error}")
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html class="no-js js-menubar" lang="en">
#  <head>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-0Z9Z2N6ZD0">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-0Z9Z2N6ZD0');
#   </script>
#   <!-- Google Analytics -->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-66287-6', 'auto');
# ga('send', 'pageview');
#   </script>
#   <!-- End Google Analytics -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimal-ui" name="viewport"/>
#   <meta content="" name="author"/>
#   <title>
#    TFRRS | College Track &amp; Field Rankings and Meet Results
#   </title>
#   <meta content="authenticity_token" name="csrf-param">
#    <meta content="yB5Bd3iAX0RvAyEeqo6REzIEoryXnCnuX8u4kVs6_cgoqmS8Birh_USu6a0EdVb_ew0t4Jil6KRXs9AYcfOdEg" name="csrf-token">
#     <link data-turbo-track="reload" href="/assets/application-a1113638bc156e6e214c8f9c53207d764d24305a643c770eec0a2eebfd1b4f8e.css" rel="stylesheet"/>
#     <script data-turbo-track="reload" defer="defer" src="/assets/application-d4008ddeb261f22a9f53f3dddd43752869320b84c550fd43799c92ffa08750df.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/jquery.min-3e889c340ba9f9e88ff5f1badaeaceec65dd060a0232a85eb144c9b62b2786fe.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/typeahead.bundle.min-d18d792426fa7f0a9679ed2c33e71307a8fe09561df9f593465a4d6feba70aec.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/tablesaw.jquery.min-4701cd748c6834f95c3161b48f459469158169ddf7c12219be1c12c34481dd59.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/tablesaw-init.min-1d6a00c96918bd12190e2fb280b0f5517d523937ed1845e65f13c4ab26130352.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/jquery.tablesorter.min-fe520a3599ba9fc81844e8160254f452265de294151587c5dc8389022a0c404a.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/widget-filter.min-1d2e9572bc5b838def30b532beaadf466ec4a4232e1a5a29088cccc092fe3086.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/jquery-asScrollbar.min-c9765e34bfd33c5bc144253cdfccb3f2347afc9c3c92a8c8adf041183bc8913e.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/jquery-asScrollable.min-581394978134953074cf3346996ad52e1d43ce9255c4c6ea05975833b502b8d0.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/breakpoints-c357bc89f972ec2735029b3c3bc86bd4d54625b8347d4347ab57a1fdff2b027b.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/babel-external-helpers-3bb9d34dcbba0de2bc460fb97b17cb78345d4df3873425d88dab40ff8c29b93e.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/tether.min-1ca7b7364b258390c80bd1394bc5f3eda891b8c0b012b8ef26e03a9d369616ca.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/popper.min-a35160b48a83891e024ad0e561f6d718eb47b9da1e8c8591f564894d30e49453.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap.min-b7e4b4eb09e42019e53eb11387a89ad1e4a7ca09a3b705c43db6167a5f4f37fa.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/State-22323558f7bdfbe6ee1fe771491a431bbdd0206669a8804bd9d7ed2340563e85.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/Component-d3b4189b709f8f5f34cda43509ddc3c24c69e13aa07fdcd150eb6de5a5e5567c.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/Plugin-c667fcb4a45c3b7fe8291856a03f82025b733501885d532ed91ddaf9899c37d5.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/Base-fdda45b3789c693e7e36db949b8455a47ad123039e8e1c80873d29f6196c6017.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/Menubar-ca18355478b4182b2c6fd46e39e576692fb46ebb338e3697af3294be001dc091.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/Sidebar-2b8a4fb8775cad5c8f48b4e9072c520a128c93de44277a03f356ffccd442f049.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/PageAside-9e225775b27ecd8847c282f548f820399a4d261977a154d240f4d042dbc2264c.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/menu-92ed59eeb67da3f42ee4a3919171b2cce1b94d01d0e781f427979eab697c30b9.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/AssetSite-820c527b2f05e216e7844316f29636d287a82e7622a8312b28ed7da37413ec28.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap-datepicker.min-f3fcc2903d76b2cdb29452b3f0256c90772fd3beeb7818be185aaa4db6362a0a.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/bootstrap-select.min-281407c5f68d119b06e38b696397e1d8139e5fe6052bb203b9b7e545059035d7.js">
#     </script>
#     <script data-turbo-track="reload" defer="defer" src="/assets/init-2e09e52e809bcfa5e2219133005caefc381babaf24f41ad12cb56fb58adf3711.js">
#     </script>
#     <link data-turbo-track="reload" href="/assets/bootstrap.min-ea362e84a9f5cc626295a685aca36b51950bedfa00454f5eb8ae1f2454484a2f.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/bootstrap-extend.min-e818edbc82dcdb6c8a15c7b7830852f21184d7014b58337689186b7b03528bca.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/site-58a6a8df1b1f345f7102340bcec41da64ef5209b33e8d662b2fe47830220de20.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/main-19d90a676b47e99838610a8cdd53f709fe0abffc40cd0e72567547f3f3b99de2.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/tablesaw-9aadb8b0a807a577c968d42d977f70b89acbca55dfba8784138576dd9f14587f.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/asScrollable-bf8159f60730f7391f091c5807a2c0f1e0ddbae2c3708dc87a8dd2125ef27829.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/typeahead.min-ca8d2708c2f18195741f87b0e469a4e99688b7fb67bc179553e089863af5d550.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/Roboto-23a1c1e33751bd43df85d705836b96b590f2f13a491e7687c932835aa0b069d1.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/proxima-nova-46208f674a9effe7c048ac37d6c7ef4f356e45f975c293696e48c65ee327fded.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/font-awesome-ce93c9293a2ef156c2930be8f14768ebfb33d213bf3159eb0c982eb201e1f3b0.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/material-design.min-7954ef339aa441ba58fdeba9c480b4e44b7a276f423568a58c6ecfa2f1306c57.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/frame-support-9304d5b0bd8d10156c6ba27255a589b0583833ed622210120063cdc471ed8fae.css" rel="stylesheet"/>
#     <link data-turbo-track="reload" href="/assets/bootstrap-select.min-b248e59e991ebc495c96bdfce4c677452becca97820ea670a23d508a82a52adf.css" rel="stylesheet"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-60x60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-76x76.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#     <link href="//assets.tfrrs.org/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#     <link href="//assets.tfrrs.org/images/favicons/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
#     <link href="//assets.tfrrs.org/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#     <link href="//assets.tfrrs.org/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="//assets.tfrrs.org/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#     <link href="//assets.tfrrs.org/images/favicons/favicon-128.png" rel="icon" sizes="128x128" type="image/png"/>
#     <meta content=" " name="application-name">
#      <meta content="#FFFFFF" name="msapplication-TileColor">
#       <meta content="//assets.tfrrs.org/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#       <meta content="//assets.tfrrs.org/images/favicons/mstile-70x70.png" name="msapplication-square70x70logo"/>
#       <meta content="//assets.tfrrs.org/images/favicons/mstile-150x150.png" name="msapplication-square150x150logo"/>
#       <meta content="//assets.tfrrs.org/images/favicons/mstile-310x150.png" name="msapplication-wide310x150logo"/>
#       <meta content="//assets.tfrrs.org/images/favicons/mstile-310x310.png" name="msapplication-square310x310logo"/>
#       <style>
#        ::-webkit-scrollbar {
#     width:9px;
# }
#
# ::-webkit-scrollbar-track {
#     -webkit-border-radius:5px;
#     border-radius:5px;
#     background:rgba(0,0,0,0.1);
# }
#
# ::-webkit-scrollbar-thumb {
#     -webkit-border-radius:5px;
#     border-radius:5px;
#     background:rgba(0,0,0,0.2);
# }
#
# ::-webkit-scrollbar-thumb:hover {
#     background:rgba(0,0,0,0.4);
# }
#
# ::-webkit-scrollbar-thumb:window-inactive {
#     background:rgba(0,0,0,0.05);
# }
#
# #scrollable-dropdown-menu .tt-menu {
#   max-height: 150px;
#   overflow-y: scroll;
# }
#
# .no-scrollbar::-webkit-scrollbar {
#   display: none;
# }
#
# .hoka-navbar-brand-logo {
#     height: 40px !important;
# }
#
# img.hoka-navbar-brand-logo {
#     display: inline-block;
#     vertical-align: top;
# }
#       </style>
#       <script async="" src="https://99bad415-a15a-4792-bd4c-dd79f2848ebb.redfastlabs.com/assets/redfast.js">
#       </script>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="page-body" style="background-image: url('//assets.tfrrs.org/images/da_xc_bg.jpg') ;">
#   <nav class="site-navbar navbar navbar-default navbar-mega hidden-lg-up hidden-md-up" role="navigation">
#    <div class="container">
#     <div class="navbar-header">
#      <div class="navbar-brand">
#       <a class="navbar-brand-logo" href="//www.tfrrs.org">
#        <img class="navbar-brand-logo" src="//assets.tfrrs.org/images/TFRRS_XC_157x30.png" title="TFRRS-XC LOGO"/>
#       </a>
#       <span style="font-size:27px;color:gray;position:relative; top:10px;">
#        /
#       </span>
#       <img class="hoka-navbar-brand-logo" src="//assets.tfrrs.org/sponsor/hoka/hoka_blue.png" title="HOKA Logo">
#       </img>
#      </div>
#     </div>
#    </div>
#   </nav>
#   <div class="site-menu-mobile">
#    <button class="navbar-toggler hamburger hamburger-close navbar-toggler-left hided" data-toggle="menubar" type="button">
#     <span class="sr-only">
#      Toggle navigation
#     </span>
#     <span class="hamburger-bar">
#     </span>
#    </button>
#   </div>
#   <div class="site-menubar">
#    <div class="site-menubar-body container">
#     <div>
#      <div>
#       <div class="inline-block site-menu-logo">
#        <a href="//www.tfrrs.org">
#         <img class="mb-15 w-200" src="//assets.tfrrs.org/images/TFRRS_XC_200x38.png" title=""/>
#        </a>
#        <span style="font-size:36px;vertical-align: bottom;">
#         /
#        </span>
#        <img height="58px" src="//assets.tfrrs.org/sponsor/hoka/hoka_blue.png" title="HOKA Logo">
#        </img>
#       </div>
#       <ul class="site-menu inline-block ml-lg-40" data-plugin="menu">
#        <li class="site-menu-item has-sub">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           TEAMS
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down mt-10">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <div class="input-group m-20 w-250 hidden-sm-down">
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="team_search" name="team_search" onkeypress="teamKeyPress(event)" placeholder="Search for a team..." type="text"/>
#            </div>
#            <span class="input-group-btn">
#             <div class="btn btn-primary" onclick="teamsSubmit()">
#              <i aria-hidden="true" class="fa fa-search">
#              </i>
#             </div>
#            </span>
#           </div>
#           <div class="input-search clearfix hidden-lg-up hidden-md-up input-search-menu">
#            <button class="input-search-btn" type="submit">
#             <i aria-hidden="true" class="fa fa-search">
#             </i>
#            </button>
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="mobile_team_search" name="mobile_team_search" placeholder="Search Teams" type="text"/>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item has-sub">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           CONFERENCES
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down mt-10">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <div class="input-group m-20 w-250 hidden-sm-down" id="scrollable-dropdown-menu">
#            <input class="form-control" id="conference_search" name="conference_search" onkeypress="conferenceKeyPress(event)" placeholder="Search for a conference..." type="text"/>
#            <span class="input-group-btn">
#             <div class="btn btn-primary" onclick="conferenceSubmit();">
#              <i aria-hidden="true" class="fa fa-search">
#              </i>
#             </div>
#            </span>
#           </div>
#           <div class="input-search clearfix hidden-lg-up hidden-md-up input-search-menu">
#            <button class="input-search-btn" type="submit">
#             <i aria-hidden="true" class="fa fa-search">
#             </i>
#            </button>
#            <div id="scrollable-dropdown-menu">
#             <input class="form-control" id="mobile_conference_search" name="mobile_conference_search" placeholder="Search Conferences" type="text"/>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://www.tfrrs.org/results_search.html">
#          <span class="">
#           RESULTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item has-sub hidden-sm-down">
#         <a class="waves-effect waves-classic" dropdown-badge="false" style="color:#4c4654">
#          <span class="">
#           LISTS
#          </span>
#          <i aria-hidden="true" class="site-menu-arrow fa fa-chevron-down">
#          </i>
#         </a>
#         <ul class="site-menu-sub">
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/indoor_lists.html">
#            <span class="site-menu-title">
#             INDOOR LISTS
#            </span>
#           </a>
#          </li>
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/outdoor_lists.html">
#            <span class="site-menu-title">
#             OUTDOOR LISTS
#            </span>
#           </a>
#          </li>
#          <li class="site-menu-item">
#           <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/archives.html">
#            <span class="site-menu-title">
#             ARCHIVES
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://tf.tfrrs.org/indoor_lists.html">
#          <span>
#           INDOOR LISTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="waves-effect waves-classic" dropdown-badge="false" href="https://tf.tfrrs.org/outdoor_lists.html">
#          <span>
#           OUTDOOR LISTS
#          </span>
#         </a>
#        </li>
#        <li class="site-menu-item hidden-md-up hidden-lg-up hidden-xl-up">
#         <a class="animsition-link waves-effect waves-classic" href="https://tf.tfrrs.org/archives.html">
#          <span>
#           ARCHIVES
#          </span>
#         </a>
#        </li>
#        <turbo-frame class="inline-block float-right" id="login_nav" src="/loginNavigation.html">
#        </turbo-frame>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    pages = 5;
#     current_page = 1;
#     function prevPage() {
#         if (current_page > 1) {
#             showPage(current_page -1);
#         }
#     }
#
#
#     function nextPage() {
#         if (current_page < pages) {
#             showPage(current_page +1);
#         }
#     }
#
#     function showPage(page) {
#         for (var p = 1; p <= pages; p++) {
#             if (p == page) {
#                 current_page = p;
#                 $('#results_page' + p).css('display', '');
#
#                 if (p == 1) {
#                     $('.page-item[data-value="1"]').addClass("active");
#                 } else if (p == 2) {
#                     $('.page-item[data-value="2"]').addClass("active");
#                 } else if (p == 3) {
#                     $('.page-item[data-value="3"]').addClass("active");
#                 } else if (p == 4) {
#                     $('.page-item[data-value="4"]').addClass("active");
#                 } else if (p == 5) {
#                     $('.page-item[data-value="5"]').addClass("active");
#                 }
#
#             } else {
#                 $('#results_page' + p).css('display', 'none');
#                 $('.page-item[data-value="'+p+'"]').removeClass("active");
#             }
#         }
#
#         if (page != 1) {
#             $('.page-item[data-value="1"]').removeClass("active");
#         }
#
#         if (page != 2) {
#             $('.page-item[data-value="2"]').removeClass("active");
#         }
#
#         if (page != 3) {
#             $('.page-item[data-value="3"]').removeClass("active");
#         }
#
#         if (page != 4) {
#             $('.page-item[data-value="4"]').removeClass("active");
#         }
#
#         if (page != 5) {
#             $('.page-item[data-value="5"]').removeClass("active");
#         }
#     }
#   </script>
#   <div class="page container">
#    <div class="page-content panel-container">
#     <div class="row">
#      <div class="col-lg-8">
#       <div class="panel panel-bordered">
#        <div class="panel-heading xc-heading">
#         <h3 class="panel-title">
#          LATEST RESULTS
#         </h3>
#         <ul class="panel-actions panel-actions-keep">
#          <li>
#           <a data-turbo="false" href="https://www.tfrrs.org/results.rss">
#            <img class="rss-button" src="//assets.tfrrs.org/images/rss-icon.png"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="panel-body pt-1 pr-1 pb-20 pl-1">
#         <table class="tablesaw tablesaw-xc table-striped table-bordered table-hover" data-tablesaw-mode="columntoggle">
#          <thead>
#           <tr>
#            <th data-tablesaw-priority="persist" scope="col">
#             DATE
#            </th>
#            <th scope="col">
#             MEET NAME
#            </th>
#            <th data-tablesaw-priority="1" scope="col">
#             STATE
#            </th>
#            <th data-tablesaw-priority="2" scope="col">
#             VENUE
#            </th>
#           </tr>
#          </thead>
#          <tbody id="results_page1">
#           <tr>
#            <td>
#             Oct 10
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24847/PVAMU_Clifton_Gillard_Cross_Country">
#              PVAMU Clifton Gillard Cross Country
#             </a>
#            </td>
#            <td>
#             TX
#            </td>
#            <td>
#             Prairie View
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  9
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24924/Principia_Twilight">
#              Principia Twilight
#             </a>
#            </td>
#            <td>
#             IL
#            </td>
#            <td>
#             Principia
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  8
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25017/CCNY_John_Jay_Dual">
#              CCNY John Jay Dual
#             </a>
#            </td>
#            <td>
#             NY
#            </td>
#            <td>
#             CCNY
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  6
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23989/Queensborough_Cross_Country_Invitational">
#              Queensborough Cross Country Invitational
#             </a>
#            </td>
#            <td>
#             NY
#            </td>
#            <td>
#             Van Cortland Park
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23689/Ted_Castaneda_XC_Classic">
#              Ted Castaneda XC Classic
#             </a>
#            </td>
#            <td>
#             CO
#            </td>
#            <td>
#             Colorado College
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23609/Belhaven_Invitational">
#              Belhaven Invitational
#             </a>
#            </td>
#            <td>
#             MS
#            </td>
#            <td>
#             Choctaw Trails
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24204/2024_Kara_Hall_Memorial_Invitational">
#              2024 Kara Hall Memorial Invitational
#             </a>
#            </td>
#            <td>
#             NY
#            </td>
#            <td>
#             Fredonia State
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24390/Lehigh_Paul_Short_Run_College">
#              Lehigh Paul Short Run (College)
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Lehigh
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24629/Missouri_Western_State_Griffon_Invite">
#              Missouri Western State Griffon Invite
#             </a>
#            </td>
#            <td>
#             MO
#            </td>
#            <td>
#             Missouri Western
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24927/Whitman_XC_Invite">
#              Whitman XC Invite
#             </a>
#            </td>
#            <td>
#             WA
#            </td>
#            <td>
#             Whitman College
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23778/DBU_Old_Glory_Gallop">
#              DBU Old Glory Gallop
#             </a>
#            </td>
#            <td>
#             TX
#            </td>
#            <td>
#             Dallas Baptist
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25012/Briar_Cliff_XC_Invitational_">
#              Briar Cliff XC Invitational
#             </a>
#            </td>
#            <td>
#             IA
#            </td>
#            <td>
#             Briar Cliff
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23840/Newberry_XC_Invite">
#              Newberry XC Invite
#             </a>
#            </td>
#            <td>
#             SC
#            </td>
#            <td>
#             Newberry
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25014/Louisville_Classic">
#              Louisville Classic
#             </a>
#            </td>
#            <td>
#             KY
#            </td>
#            <td>
#             E.P. Tom Sawyer State Park
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25090/CAMPY_Invitational">
#              CAMPY Invitational
#             </a>
#            </td>
#            <td>
#             AZ
#            </td>
#            <td>
#             Central Arizona
#            </td>
#           </tr>
#          </tbody>
#          <tbody id="results_page2" style="display:none">
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24454/Golden_Eagle_Invitational">
#              Golden Eagle Invitational
#             </a>
#            </td>
#            <td>
#             AR
#            </td>
#            <td>
#             Pollards Field
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25013/Keene_State_College_Invitational">
#              Keene State College Invitational
#             </a>
#            </td>
#            <td>
#             NH
#            </td>
#            <td>
#             Keene State
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24374/Sauk_Valley_Skyhawk_Invitational">
#              Sauk Valley Skyhawk Invitational
#             </a>
#            </td>
#            <td>
#             IL
#            </td>
#            <td>
#             Sauk Valley Communtiy College
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25011/Pitt_Greensburg_Fall_Classic_">
#              Pitt Greensburg Fall Classic
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Pitt.-Greensburg
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25015/Carleton_Running_of_the_Cows">
#              Carleton Running of the Cows
#             </a>
#            </td>
#            <td>
#             MN
#            </td>
#            <td>
#             Carleton College
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25093/Penn_State_Brandywine_Invite">
#              Penn State Brandywine Invite
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             PSU-Brandywine
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24317/Louisiana_Tech_Mook_4_">
#              Louisiana Tech Mook 4
#             </a>
#            </td>
#            <td>
#             LA
#            </td>
#            <td>
#             Louisiana Tech
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23604/24th_Annual_Warrior_Invitational">
#              24th Annual Warrior Invitational
#             </a>
#            </td>
#            <td>
#             WI
#            </td>
#            <td>
#             Wisconsin Lutheran
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24110/Ave_Maria_Invitational_">
#              Ave Maria Invitational
#             </a>
#            </td>
#            <td>
#             FL
#            </td>
#            <td>
#             Ave Maria
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24829/Dan_Huston_Invitational">
#              Dan Huston Invitational
#             </a>
#            </td>
#            <td>
#             IA
#            </td>
#            <td>
#             Wartburg
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24457/Hawaii-Hilo_Invitational">
#              Hawaii-Hilo Invitational
#             </a>
#            </td>
#            <td>
#             HI
#            </td>
#            <td>
#             Hawaii-Hilo
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23762/Greyhound_Invite">
#              Greyhound Invite
#             </a>
#            </td>
#            <td>
#             NM
#            </td>
#            <td>
#             Eastern New Mexico
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24066/Seminole_Valley_Stampede">
#              Seminole Valley Stampede
#             </a>
#            </td>
#            <td>
#             IA
#            </td>
#            <td>
#             Mount Mercy
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23337/49th_Charles_Bowles_Willamette_XC_Invitational_-_COLLEGE_TEAMS">
#              49th Charles Bowles Willamette XC Invitational - COLLEGE TEAMS
#             </a>
#            </td>
#            <td>
#             OR
#            </td>
#            <td>
#             Willamette
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24337/Mountain_Goat_Invitational">
#              Mountain Goat Invitational
#             </a>
#            </td>
#            <td>
#             TN
#            </td>
#            <td>
#             U. of the South
#            </td>
#           </tr>
#          </tbody>
#          <tbody id="results_page3" style="display:none">
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24000/BATES_INVITATIONAL">
#              BATES INVITATIONAL
#             </a>
#            </td>
#            <td>
#             ME
#            </td>
#            <td>
#             Pineland Farms
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23367/Highlander_Invitational">
#              Highlander Invitational
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Cairn University
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23323/D3_Pre-Nationals">
#              D3 Pre-Nationals
#             </a>
#            </td>
#            <td>
#             IN
#            </td>
#            <td>
#             La Vern Gibson Championship XC Course
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23450/Sweet_Briar_Invitational">
#              Sweet Briar Invitational
#             </a>
#            </td>
#            <td>
#             VA
#            </td>
#            <td>
#             Sweet Briar
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24126/UW-Eau_Claire_Blugold_Invitational">
#              UW-Eau Claire Blugold Invitational
#             </a>
#            </td>
#            <td>
#             WI
#            </td>
#            <td>
#             Wisc. Eau Claire
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24246/Toro_Park_Invitational_Norcal_Preview_Meet">
#              Toro Park Invitational (Norcal Preview Meet)
#             </a>
#            </td>
#            <td>
#             CA
#            </td>
#            <td>
#             Hartnell
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23967/Georgia_Tech_XC_Invitational">
#              Georgia Tech XC Invitational
#             </a>
#            </td>
#            <td>
#             GA
#            </td>
#            <td>
#             Bouckaert Farms
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24741/NCCC_Invite">
#              NCCC Invite
#             </a>
#            </td>
#            <td>
#             KS
#            </td>
#            <td>
#             Neosho County CC
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24391/Lehigh_Paul_Short_Run_High_School">
#              Lehigh Paul Short Run (High School)
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Lehigh
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25006/Cadet_XC_Invitational">
#              Cadet XC Invitational
#             </a>
#            </td>
#            <td>
#             VT
#            </td>
#            <td>
#             Norwich University
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23362/2024_Pirate_Cross_Country_Invitational_">
#              2024 Pirate Cross Country Invitational
#             </a>
#            </td>
#            <td>
#             NC
#            </td>
#            <td>
#             East Carolina
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25010/SDSU_Classic">
#              SDSU Classic
#             </a>
#            </td>
#            <td>
#             SD
#            </td>
#            <td>
#             South Dakota St.
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23041/Ben_Snelling_Cancer_Classic_-_Day_1">
#              Ben Snelling Cancer Classic - Day 1
#             </a>
#            </td>
#            <td>
#             NC
#            </td>
#            <td>
#             Owens Park
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24848/Jimmie_XC_Invitational">
#              Jimmie XC Invitational
#             </a>
#            </td>
#            <td>
#             ND
#            </td>
#            <td>
#             Jamestown
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23885/Sean_Earl_Loyola_Lakefront_Invite">
#              Sean Earl Loyola Lakefront Invite
#             </a>
#            </td>
#            <td>
#             IL
#            </td>
#            <td>
#             Montrose Avenue Beach
#            </td>
#           </tr>
#          </tbody>
#          <tbody id="results_page4" style="display:none">
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24347/WALTERS_STATE_HALF_MARATHON">
#              WALTERS STATE HALF MARATHON
#             </a>
#            </td>
#            <td>
#             TN
#            </td>
#            <td>
#             Walters State CC
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4- 5
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25007/Great_American_XC_Festival">
#              Great American XC Festival
#             </a>
#            </td>
#            <td>
#             NC
#            </td>
#            <td>
#             WakeMed Soccer Park
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/25005/Joe_Piane_Notre_Dame_Invitational">
#              Joe Piane Notre Dame Invitational
#             </a>
#            </td>
#            <td>
#             IN
#            </td>
#            <td>
#             Notre Dame
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23783/Loyola_Invitational">
#              Loyola Invitational
#             </a>
#            </td>
#            <td>
#             LA
#            </td>
#            <td>
#             Loyola-New Orleans
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24425/OWU_Invitational">
#              OWU Invitational
#             </a>
#            </td>
#            <td>
#             OH
#            </td>
#            <td>
#             Ohio Wesleyan
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23946/Dan_Talbot_Open">
#              Dan Talbot Open
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Bryn Mawr
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23923/2024_SoCal_XC_Preview_Meet">
#              2024 SoCal XC Preview Meet
#             </a>
#            </td>
#            <td>
#             CA
#            </td>
#            <td>
#             Chaffey
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  4
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24812/Yellowjackets_Battlin_Bears_Open">
#              Yellowjackets/Battlin' Bears Open
#             </a>
#            </td>
#            <td>
#             MT
#            </td>
#            <td>
#             Montana State-Billings
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Oct  3
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23633/Gulf_Coast_State_College_Womens_Invite">
#              Gulf Coast State College Women’s Invite
#             </a>
#            </td>
#            <td>
#             FL
#            </td>
#            <td>
#             Majette Park
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24922/Bryn_Athyn_Invite">
#              Bryn Athyn Invite
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Bryn Athyn
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24884/SUNY_Poly_Wildcat_Invitational">
#              SUNY Poly Wildcat Invitational
#             </a>
#            </td>
#            <td>
#             NY
#            </td>
#            <td>
#             SUNY Polytechnic Institute
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23410/Hornet_Harrier_Invitational__Commonwealth_Challenge">
#              Hornet Harrier Invitational &amp; Commonwealth Challenge
#             </a>
#            </td>
#            <td>
#             VA
#            </td>
#            <td>
#             Kernstown Battlefield
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23639/6th_Annual_Nicholls_XC_Invitational_presented_by_Walk-Ons">
#              6th Annual Nicholls XC Invitational presented by Walk-On's
#             </a>
#            </td>
#            <td>
#             LA
#            </td>
#            <td>
#             Nicholls State
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23698/Topper_Trails_College_Classic">
#              Topper Trails College Classic
#             </a>
#            </td>
#            <td>
#             MS
#            </td>
#            <td>
#             Blue Mountain
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24891/Trevecca__Michael_Pretorius_Memorial">
#              Trevecca/ Michael Pretorius Memorial
#             </a>
#            </td>
#            <td>
#             TN
#            </td>
#            <td>
#             Percy Warner Park XC Course
#            </td>
#           </tr>
#          </tbody>
#          <tbody id="results_page5" style="display:none">
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23888/Caldwell_Cougar_Chase_Invite">
#              Caldwell Cougar Chase Invite
#             </a>
#            </td>
#            <td>
#             NJ
#            </td>
#            <td>
#             Caldwell
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23863/Dave_Murray_Invitational">
#              Dave Murray Invitational
#             </a>
#            </td>
#            <td>
#             AZ
#            </td>
#            <td>
#             Arizona
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24887/Wildcat_XC_Invite">
#              Wildcat XC Invite
#             </a>
#            </td>
#            <td>
#             NE
#            </td>
#            <td>
#             Wayne State (Neb.)
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23707/Fred_Pavlich_Invitational">
#              Fred Pavlich Invitational
#             </a>
#            </td>
#            <td>
#             NY
#            </td>
#            <td>
#             Bard College
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24885/Penn_State_Fayette_8th_Annual_Roaring_LionsInvitational">
#              Penn State Fayette 8th Annual Roaring LionsInvitational
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             PSU-Fayette
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/24029/Dickinson_Long-Short_Invitational_">
#              Dickinson Long-Short Invitational
#             </a>
#            </td>
#            <td>
#             PA
#            </td>
#            <td>
#             Big Spring High School
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23769/Calvin_Knight_Invite">
#              Calvin Knight Invite
#             </a>
#            </td>
#            <td>
#             MI
#            </td>
#            <td>
#             Calvin University
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
#             <a data-turbo="false" data-turbo-frame="_top" href="/results/xc/23668/GCSU_Bobcat_Invite">
#              GCSU Bobcat Invite
#             </a>
#            </td>
#            <td>
#             GA
#            </td>
#            <td>
#             GC&amp;SU
#            </td>
#           </tr>
#           <tr>
#            <td>
#             Sep 28
#            </td>
#            <td>
# ...
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: Calvin Knight Invite_table_1.csv
# File saved: Calvin Knight Invite_table_2.csv
# File saved: Calvin Knight Invite_table_3.csv
# File saved: Calvin Knight Invite_table_4.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: GCSU Bobcat Invite_table_1.csv
# File saved: GCSU Bobcat Invite_table_2.csv
# File saved: GCSU Bobcat Invite_table_3.csv
# File saved: GCSU Bobcat Invite_table_4.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: Chile Pepper XC Festival_table_1.csv
# File saved: Chile Pepper XC Festival_table_2.csv
# File saved: Chile Pepper XC Festival_table_3.csv
# File saved: Chile Pepper XC Festival_table_4.csv
# File saved: Chile Pepper XC Festival_table_5.csv
# File saved: Chile Pepper XC Festival_table_6.csv
# File saved: Chile Pepper XC Festival_table_7.csv
# File saved: Chile Pepper XC Festival_table_8.csv
# File saved: Chile Pepper XC Festival_table_9.csv
# File saved: Chile Pepper XC Festival_table_10.csv
# File saved: Chile Pepper XC Festival_table_11.csv
# File saved: Chile Pepper XC Festival_table_12.csv
# File saved: Chile Pepper XC Festival_table_13.csv
# File saved: Chile Pepper XC Festival_table_14.csv
# File saved: Chile Pepper XC Festival_table_15.csv
# File saved: Chile Pepper XC Festival_table_16.csv
# File saved: Chile Pepper XC Festival_table_17.csv
# File saved: Chile Pepper XC Festival_table_18.csv
# File saved: Chile Pepper XC Festival_table_19.csv
# File saved: Chile Pepper XC Festival_table_20.csv
# File saved: Chile Pepper XC Festival_table_21.csv
# File saved: Chile Pepper XC Festival_table_22.csv
# File saved: Chile Pepper XC Festival_table_23.csv
# File saved: Chile Pepper XC Festival_table_24.csv
# File saved: Mountie Invitational_table_1.csv
# File saved: Mountie Invitational_table_2.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: Mountie Invitational_table_3.csv
# File saved: Mountie Invitational_table_4.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: 2024 Cougar Challenge_table_1.csv
# File saved: 2024 Cougar Challenge_table_2.csv
# File saved: 2024 Cougar Challenge_table_3.csv
# File saved: 2024 Cougar Challenge_table_4.csv
# File saved: Jessup Cross Country Invitational_table_1.csv
# File saved: Jessup Cross Country Invitational_table_2.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# File saved: Harry F. Anderson Invitational_table_1.csv
# File saved: Harry F. Anderson Invitational_table_2.csv
# File saved: Harry F. Anderson Invitational_table_3.csv
# File saved: Harry F. Anderson Invitational_table_4.csv
# File saved: Thomas Invitational_table_1.csv
# File saved: Thomas Invitational_table_2.csv
# File saved: Thomas Invitational_table_3.csv
# File saved: Thomas Invitational_table_4.csv
# File saved: Brown Bear Invitational_table_1.csv
# File saved: Brown Bear Invitational_table_2.csv
# File saved: Brown Bear Invitational_table_3.csv
# File saved: Brown Bear Invitational_table_4.csv
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
# <ipython-input-1-4448489a9714>:76: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_frames.append(pd.read_html(str(table))[0])
